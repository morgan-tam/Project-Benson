# %%
from __future__ import print_function, division

# %%
from collections import defaultdict
import csv
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import os

# %matplotlib inline

# %% [markdown]
# 'path' is where all the data files are on my computer. Another way to get the data without downloading them manually is below.

# %%
path = '/Users/aleksandra/ds/metis/Project-Benson/data_mta/'

# %%
def read_data(path):
    '''opens all txt files in the given directory and creates a df'''
    all_data = pd.DataFrame()
    for filename in os.listdir(path):
        with open(path+str(filename)) as f:
            df = pd.read_csv(f)
            all_data = all_data.append(df)
    all_data.columns = ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME','DESC', 'ENTRIES', 'EXITS']
    return all_data

def save_as_csv(df, path):
    '''saves df in given directory'''
    df.to_csv(path+'all_data.csv')

# %% [markdown]
# Below is the Metis code to get all the data and put them in a data frame.

# %%
def get_data(week_nums):
    '''NOT MY CODE. downlaods all files in the list of weeks and puts them in a pandas df'''
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)

# %%
data = read_data(path)

# %%
data.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  5682962  1924340
# 1  REGULAR  5683000  1924347
# 2  REGULAR  5683030  1924381
# 3  REGULAR  5683175  1924474
# 4  REGULAR  5683437  1924533

# %%
data.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 192673  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
# 192674  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
# 192675  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
# 192676  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
# 192677  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
#
#             TIME     DESC  ENTRIES  EXITS
# 192673  05:00:00  REGULAR     5554    271
# 192674  09:00:00  REGULAR     5554    271
# 192675  13:00:00  REGULAR     5554    271
# 192676  17:00:00  REGULAR     5554    271
# 192677  21:00:00  REGULAR     5554    271

# %%
data.DATE.value_counts()
# for each date, give me the number of rows.
# Out:
# 09/06/2016    28826
# 06/07/2016    28816
# 08/01/2016    28611
# 06/27/2016    28342
# 07/05/2016    28268
# 06/14/2016    28263
# 07/11/2016    28218
# 06/13/2016    28200
# 06/20/2016    28189
# 07/21/2016    28170
# 09/16/2016    28160
# 09/21/2016    28151
# 09/08/2016    28137
# 09/01/2016    28116
# 06/23/2016    28104
# 07/19/2016    28095
# 09/12/2016    28074
# 08/09/2016    28044
# 06/22/2016    28026
# 06/29/2016    28022
# 05/31/2016    28017
# 07/07/2016    28001
# 06/08/2016    27986
# 09/07/2016    27977
# 09/09/2016    27956
# 08/04/2016    27917
# 08/11/2016    27885
# 07/12/2016    27872
# 06/01/2016    27863
# 07/13/2016    27860
#               ...
# 08/28/2016    27300
# 08/15/2016    27299
# 08/16/2016    27296
# 08/27/2016    27290
# 07/28/2016    27289
# 09/15/2016    27283
# 07/17/2016    27282
# 07/10/2016    27275
# 07/08/2016    27274
# 08/20/2016    27270
# 07/16/2016    27262
# 08/13/2016    27262
# 06/28/2016    27259
# 08/26/2016    27258
# 08/07/2016    27258
# 07/09/2016    27257
# 07/30/2016    27253
# 08/03/2016    27249
# 09/23/2016    27242
# 07/23/2016    27228
# 07/20/2016    27224
# 09/22/2016    27221
# 07/25/2016    27213
# 08/17/2016    27200
# 07/31/2016    27200
# 08/14/2016    27188
# 07/24/2016    27186
# 07/29/2016    27160
# 08/18/2016    27149
# 08/19/2016    27146
# Name: DATE, dtype: int64

# %% [markdown]
# Add a column that contains both date and time in datetime format

# %%
data['DATE_TIME'] = pd.to_datetime(data['DATE'] +' ' + data['TIME'], format = '%m/%d/%Y %H:%M:%S')

# %%
data.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME
# 0  REGULAR  5682962  1924340 2016-05-28 00:00:00
# 1  REGULAR  5683000  1924347 2016-05-28 04:00:00
# 2  REGULAR  5683030  1924381 2016-05-28 08:00:00
# 3  REGULAR  5683175  1924474 2016-05-28 12:00:00
# 4  REGULAR  5683437  1924533 2016-05-28 16:00:00

# %% [markdown]
# Next thing to do is to check the cleanliness of the data:
# * There should be one single row for each turnstile (identified by the conjunction of the first four columns) per datetime
# * The number of entries from a posterior point in time should be bigger than the number of entries from a previous point in time, for a given trunstile
# * There is something about one station actually being two stations, but I will not figure that out.

# %%
turnstile = ['C/A', 'UNIT', 'SCP', 'STATION']

# %%
data.groupby(turnstile + ['DATE_TIME']).ENTRIES.count().sort_values(ascending = False)
# Out:
# C/A    UNIT  SCP       STATION          DATE_TIME
# N418   R269  01-05-00  BEDFORD-NOSTRAN  2016-08-08 12:00:00    2
# R634   R069  00-00-00  NEW LOTS AV      2016-08-20 12:00:00    2
# H032   R295  00-05-00  WILSON AV        2016-05-31 20:00:00    2
# H009   R235  00-06-01  BEDFORD AV       2016-07-04 16:00:00    2
# R634   R069  00-00-00  NEW LOTS AV      2016-08-20 20:00:00    2
# B020   R263  00-06-00  AVENUE H         2016-05-30 12:00:00    2
# H032   R295  00-05-00  WILSON AV        2016-06-01 00:00:00    2
# R634   R069  00-00-00  NEW LOTS AV      2016-08-20 16:00:00    2
# N418   R269  01-05-00  BEDFORD-NOSTRAN  2016-08-11 08:00:00    2
#                                         2016-08-10 08:00:00    2
# H009   R235  00-06-01  BEDFORD AV       2016-07-04 12:00:00    2
# N418   R269  01-05-00  BEDFORD-NOSTRAN  2016-08-11 00:00:00    2
# H032   R295  00-05-00  WILSON AV        2016-06-01 08:00:00    2
# N418   R269  01-05-00  BEDFORD-NOSTRAN  2016-08-10 20:00:00    2
#                                         2016-08-10 16:00:00    2
#                                         2016-08-10 12:00:00    2
# H009   R235  00-06-01  BEDFORD AV       2016-07-04 20:00:00    2
#                                         2016-07-05 00:00:00    2
#                                         2016-07-05 04:00:00    2
# H032   R295  00-05-00  WILSON AV        2016-05-31 16:00:00    2
# H009   R235  00-06-01  BEDFORD AV       2016-07-05 08:00:00    2
# R634   R069  00-00-00  NEW LOTS AV      2016-08-21 00:00:00    2
#                                         2016-08-21 08:00:00    2
# N339A  R114  00-00-01  PARSONS BLVD     2016-08-15 04:00:00    2
# R634   R069  00-00-00  NEW LOTS AV      2016-08-21 12:00:00    2
# N605   R024  00-00-04  SUTPHIN-ARCHER   2016-07-31 16:00:00    2
# R634   R069  00-00-00  NEW LOTS AV      2016-08-21 16:00:00    2
#                                         2016-08-21 20:00:00    2
#                                         2016-08-22 00:00:00    2
#                                         2016-08-22 08:00:00    2
#                                                               ..
# R154   R116  00-00-03  50 ST            2016-07-24 12:00:00    1
#                                         2016-07-24 08:00:00    1
#                                         2016-07-24 04:00:00    1
#                                         2016-07-24 00:00:00    1
#                                         2016-07-27 12:00:00    1
#                                         2016-07-27 20:00:00    1
#                                         2016-07-31 16:00:00    1
#                                         2016-07-28 00:00:00    1
#                                         2016-07-31 12:00:00    1
#                                         2016-07-31 08:00:00    1
#                                         2016-07-31 04:00:00    1
#                                         2016-07-31 00:00:00    1
#                                         2016-07-30 20:00:00    1
#                                         2016-07-30 16:00:00    1
#                                         2016-07-30 12:00:00    1
#                                         2016-07-30 08:00:00    1
#                                         2016-07-30 04:00:00    1
#                                         2016-07-30 00:00:00    1
#                                         2016-07-29 20:00:00    1
#                                         2016-07-29 16:00:00    1
#                                         2016-07-29 12:00:00    1
#                                         2016-07-29 08:00:00    1
#                                         2016-07-29 04:00:00    1
#                                         2016-07-29 00:00:00    1
#                                         2016-07-28 20:00:00    1
#                                         2016-07-28 16:00:00    1
#                                         2016-07-28 12:00:00    1
#                                         2016-07-28 08:00:00    1
#                                         2016-07-28 04:00:00    1
# A002   R051  02-00-00  59 ST            2016-05-28 00:00:00    1
# Name: ENTRIES, dtype: int64

# %% [markdown]
# There are several duplicates in the dataset. We need to inspect them to understand what's going on. Once we undesrtand, we can decide what to do with them.

# %%
filtre = ((data["C/A"] == "N418") & 
(data["UNIT"] == "R269") & 
(data["SCP"] == "01-05-00") & 
(data["STATION"] == "BEDFORD-NOSTRAN") &
(data["DATE_TIME"].dt.date == datetime(2016, 8, 8).date()))

# %%
data[filtre].head(20)
# Out:
#         C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 90822  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90823  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90824  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90825  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90826  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90827  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90828  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90829  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90830  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90831  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
# 90832  N418  R269  01-05-00  BEDFORD-NOSTRAN        G      IND  08/08/2016
#
#            TIME        DESC   ENTRIES     EXITS           DATE_TIME
# 90822  00:00:00     REGULAR  83886190         0 2016-08-08 00:00:00
# 90823  00:00:00  RECOVR AUD  67108866  33554496 2016-08-08 00:00:00
# 90824  04:00:00     REGULAR  83886190         0 2016-08-08 04:00:00
# 90825  08:00:00     REGULAR  83886190         0 2016-08-08 08:00:00
# 90826  08:00:00  RECOVR AUD  67108866  33554496 2016-08-08 08:00:00
# 90827  12:00:00     REGULAR  83886190         0 2016-08-08 12:00:00
# 90828  12:00:00  RECOVR AUD  67108866  33554496 2016-08-08 12:00:00
# 90829  16:00:00     REGULAR  83886190         0 2016-08-08 16:00:00
# 90830  16:00:00  RECOVR AUD  67108866  33554496 2016-08-08 16:00:00
# 90831  20:00:00     REGULAR  83886190         0 2016-08-08 20:00:00
# 90832  20:00:00  RECOVR AUD  67108866  33554496 2016-08-08 20:00:00

# %% [markdown]
# According to the documentation:
#
# DESc     = Represent the "REGULAR" scheduled audit event (Normally occurs every 4 hours)
#            1. Audits may occur more that 4 hours due to planning, or troubleshooting activities.
#            2. Additionally, there may be a "RECOVR AUD" entry: This refers to a missed audit that was recovered.
#
# All rows with DESC == 'RECOVR AUD' may be deleted

# %%
data_no_dupl = data[data.DESC != 'RECOVR AUD']

# %%
data_no_dupl.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME
# 0  REGULAR  5682962  1924340 2016-05-28 00:00:00
# 1  REGULAR  5683000  1924347 2016-05-28 04:00:00
# 2  REGULAR  5683030  1924381 2016-05-28 08:00:00
# 3  REGULAR  5683175  1924474 2016-05-28 12:00:00
# 4  REGULAR  5683437  1924533 2016-05-28 16:00:00

# %% [markdown]
# Let's see if the duplicates are gone...

# %%
data_no_dupl.groupby(turnstile + ['DATE_TIME']).ENTRIES.count().sort_values(ascending = False)
# Out:
# C/A    UNIT  SCP       STATION        DATE_TIME
# TRAM2  R469  00-05-01  RIT-ROOSEVELT  2016-09-23 21:00:00    1
# N128   R200  00-05-00  EUCLID AV      2016-08-14 20:00:00    1
#                                       2016-08-14 12:00:00    1
#                                       2016-08-14 08:00:00    1
#                                       2016-08-14 04:00:00    1
#                                       2016-08-14 00:00:00    1
#                                       2016-08-13 20:00:00    1
#                                       2016-08-13 16:00:00    1
#                                       2016-08-13 12:00:00    1
#                                       2016-08-13 08:00:00    1
#                                       2016-08-13 04:00:00    1
#                                       2016-08-13 00:00:00    1
#                                       2016-08-12 20:00:00    1
#                                       2016-08-12 16:00:00    1
#                                       2016-08-12 12:00:00    1
#                                       2016-08-12 08:00:00    1
#                                       2016-08-12 04:00:00    1
#                                       2016-08-12 00:00:00    1
#                                       2016-08-11 20:00:00    1
#                                       2016-08-11 16:00:00    1
#                                       2016-08-11 12:00:00    1
#                                       2016-08-11 08:00:00    1
#                                       2016-08-11 04:00:00    1
#                                       2016-08-14 16:00:00    1
#                                       2016-08-15 00:00:00    1
#                                       2016-08-10 20:00:00    1
#                                       2016-08-15 04:00:00    1
#                                       2016-08-18 16:00:00    1
#                                       2016-08-18 12:00:00    1
#                                       2016-08-18 08:00:00    1
#                                                             ..
# R154   R116  00-00-02  50 ST          2016-08-29 00:00:00    1
#                                       2016-08-28 20:00:00    1
#                                       2016-08-28 16:00:00    1
#                                       2016-08-28 12:00:00    1
#                                       2016-08-28 08:00:00    1
#                                       2016-09-01 00:00:00    1
#                                       2016-09-01 04:00:00    1
#                                       2016-09-01 08:00:00    1
#                                       2016-09-03 16:00:00    1
#                                       2016-09-05 04:00:00    1
#                                       2016-09-05 00:00:00    1
#                                       2016-09-04 20:00:00    1
#                                       2016-09-04 16:00:00    1
#                                       2016-09-04 12:00:00    1
#                                       2016-09-04 08:00:00    1
#                                       2016-09-04 04:00:00    1
#                                       2016-09-04 00:00:00    1
#                                       2016-09-03 20:00:00    1
#                                       2016-09-03 12:00:00    1
#                                       2016-09-01 12:00:00    1
#                                       2016-09-03 08:00:00    1
#                                       2016-09-03 04:00:00    1
#                                       2016-09-03 00:00:00    1
#                                       2016-09-02 12:00:00    1
#                                       2016-09-02 08:00:00    1
#                                       2016-09-02 04:00:00    1
#                                       2016-09-02 00:00:00    1
#                                       2016-09-01 20:00:00    1
#                                       2016-09-01 16:00:00    1
# A002   R051  02-00-00  59 ST          2016-05-28 00:00:00    1
# Name: ENTRIES, dtype: int64

# %%
# drop DESC columns, there's no useful info in there anymore
data_no_dupl = data_no_dupl.drop(['DESC'], axis = 1)

# %% [markdown]
# Next: check whether the number of entries (and exits as well if we want to track all transit through a station) actually increases with time.

# %%
data_no_dupl.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  05/28/2016  16:00:00
#
#    ENTRIES    EXITS           DATE_TIME
# 0  5682962  1924340 2016-05-28 00:00:00
# 1  5683000  1924347 2016-05-28 04:00:00
# 2  5683030  1924381 2016-05-28 08:00:00
# 3  5683175  1924474 2016-05-28 12:00:00
# 4  5683437  1924533 2016-05-28 16:00:00

# %% [markdown]
# Make a df with one row per turnstile per day. We only keep the first ocurrence of 'entries' for each day, because
# What happens during the day is not relevant for a daily analysis. It will be relevant when we want to know peak hours.

# %%
data_daily_entries = data_no_dupl.groupby(turnstile+['DATE']).ENTRIES.first().reset_index()

# %%
data_daily_entries.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES
# 0  A002  R051  02-00-00   59 ST  05/28/2016  5682962
# 1  A002  R051  02-00-00   59 ST  05/29/2016  5683957
# 2  A002  R051  02-00-00   59 ST  05/30/2016  5684749
# 3  A002  R051  02-00-00   59 ST  05/31/2016  5685506
# 4  A002  R051  02-00-00   59 ST  06/01/2016  5687282

# %%
data_daily_exits = data_no_dupl.groupby(turnstile+['DATE']).EXITS.first().reset_index()

# %%
data_daily_exits.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE    EXITS
# 0  A002  R051  02-00-00   59 ST  05/28/2016  1924340
# 1  A002  R051  02-00-00   59 ST  05/29/2016  1924599
# 2  A002  R051  02-00-00   59 ST  05/30/2016  1924791
# 3  A002  R051  02-00-00   59 ST  05/31/2016  1925050
# 4  A002  R051  02-00-00   59 ST  06/01/2016  1925601

# %%
data_daily_entries[["PREV_DATE", "PREV_ENTRIES"]] = (data_daily_entries
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION"])["DATE", "ENTRIES"]
                                                       .transform(lambda grp: grp.shift(1)))

# %%
data_daily_entries.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  PREV_ENTRIES
# 0  A002  R051  02-00-00   59 ST  05/28/2016  5682962         NaN           NaN
# 1  A002  R051  02-00-00   59 ST  05/29/2016  5683957  05/28/2016     5682962.0
# 2  A002  R051  02-00-00   59 ST  05/30/2016  5684749  05/29/2016     5683957.0
# 3  A002  R051  02-00-00   59 ST  05/31/2016  5685506  05/30/2016     5684749.0
# 4  A002  R051  02-00-00   59 ST  06/01/2016  5687282  05/31/2016     5685506.0

# %%
data_daily_exits["PREV_EXITS"] = data_daily_exits.groupby(turnstile)['EXITS'].transform(lambda grp: grp.shift(1))

# %%
data_daily_exits.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE    EXITS  PREV_EXITS
# 0  A002  R051  02-00-00   59 ST  05/28/2016  1924340         NaN
# 1  A002  R051  02-00-00   59 ST  05/29/2016  1924599   1924340.0
# 2  A002  R051  02-00-00   59 ST  05/30/2016  1924791   1924599.0
# 3  A002  R051  02-00-00   59 ST  05/31/2016  1925050   1924791.0
# 4  A002  R051  02-00-00   59 ST  06/01/2016  1925601   1925050.0

# %%
data_daily_entries[['EXITS', 'PREV_EXITS']] = data_daily_exits[['EXITS', 'PREV_EXITS']]

# %%
data_daily_entries.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 0  A002  R051  02-00-00   59 ST  05/28/2016  5682962         NaN
# 1  A002  R051  02-00-00   59 ST  05/29/2016  5683957  05/28/2016
# 2  A002  R051  02-00-00   59 ST  05/30/2016  5684749  05/29/2016
# 3  A002  R051  02-00-00   59 ST  05/31/2016  5685506  05/30/2016
# 4  A002  R051  02-00-00   59 ST  06/01/2016  5687282  05/31/2016
#
#    PREV_ENTRIES    EXITS  PREV_EXITS
# 0           NaN  1924340         NaN
# 1     5682962.0  1924599   1924340.0
# 2     5683957.0  1924791   1924599.0
# 3     5684749.0  1925050   1924791.0
# 4     5685506.0  1925601   1925050.0

# %% [markdown]
# 'data_daily_entries' now is a df which permits unique identification of each turnstile (first 4 columns), the date, the previous date, the entries and exits and previous entries and exits.
# Next: drop rows with NaN

# %%
data_daily_entries.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
data_daily_entries.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/29/2016  5683957  05/28/2016
# 2  A002  R051  02-00-00   59 ST  05/30/2016  5684749  05/29/2016
# 3  A002  R051  02-00-00   59 ST  05/31/2016  5685506  05/30/2016
# 4  A002  R051  02-00-00   59 ST  06/01/2016  5687282  05/31/2016
# 5  A002  R051  02-00-00   59 ST  06/02/2016  5689073  06/01/2016
#
#    PREV_ENTRIES    EXITS  PREV_EXITS
# 1     5682962.0  1924599   1924340.0
# 2     5683957.0  1924791   1924599.0
# 3     5684749.0  1925050   1924791.0
# 4     5685506.0  1925601   1925050.0
# 5     5687282.0  1926208   1925601.0

# %%
crazy_turnstiles = data_daily_entries[data_daily_entries["ENTRIES"] < data_daily_entries["PREV_ENTRIES"]]

# %%
crazy_turnstiles.head()
# Out:
#        C/A  UNIT       SCP     STATION        DATE    ENTRIES   PREV_DATE  \
# 3725  A010  R080  00-00-05  57 ST-7 AV  07/15/2016       1924  07/14/2016
# 4035  A011  R080  01-00-00  57 ST-7 AV  05/29/2016  887922841  05/28/2016
# 4036  A011  R080  01-00-00  57 ST-7 AV  05/30/2016  887921264  05/29/2016
# 4037  A011  R080  01-00-00  57 ST-7 AV  05/31/2016  887919921  05/30/2016
# 4038  A011  R080  01-00-00  57 ST-7 AV  06/01/2016  887916819  05/31/2016
#
#       PREV_ENTRIES      EXITS   PREV_EXITS
# 3725    10780997.0         59    3955742.0
# 4035   887924524.0  493656275  493658400.0
# 4036   887922841.0  493654483  493656275.0
# 4037   887921264.0  493652865  493654483.0
# 4038   887919921.0  493649969  493652865.0

# %%
# crazy turnstile days for enterung
len(crazy_turnstiles)
# Out:
# 4298

# %%
crazy_turnstiles_exit = data_daily_entries[data_daily_entries["EXITS"] < data_daily_entries["PREV_EXITS"]]
crazy_turnstiles_exit.head()
# Out:
#        C/A  UNIT       SCP     STATION        DATE    ENTRIES   PREV_DATE  \
# 3725  A010  R080  00-00-05  57 ST-7 AV  07/15/2016       1924  07/14/2016
# 4035  A011  R080  01-00-00  57 ST-7 AV  05/29/2016  887922841  05/28/2016
# 4036  A011  R080  01-00-00  57 ST-7 AV  05/30/2016  887921264  05/29/2016
# 4037  A011  R080  01-00-00  57 ST-7 AV  05/31/2016  887919921  05/30/2016
# 4038  A011  R080  01-00-00  57 ST-7 AV  06/01/2016  887916819  05/31/2016
#
#       PREV_ENTRIES      EXITS   PREV_EXITS
# 3725    10780997.0         59    3955742.0
# 4035   887924524.0  493656275  493658400.0
# 4036   887922841.0  493654483  493656275.0
# 4037   887921264.0  493652865  493654483.0
# 4038   887919921.0  493649969  493652865.0

# %%
# crazy turnstile days exit
len(crazy_turnstiles_exit)
# Out:
# 3676

# %%
# total number of turnstile days
len(data_daily_entries)
# Out:
# 538364

# %%
# number of turnstiles
len(data_daily_entries.groupby(turnstile))
# Out:
# 4626

# %%
# check if the crazy turnstile for exiting and entering coincide
ct_entries = crazy_turnstiles.groupby(turnstile).groups.keys()
len(ct_entries)
# Out:
# 225

# %%
ct_exits = crazy_turnstiles_exit.groupby(turnstile).groups.keys()
len(ct_exits)
# Out:
# 226

# %%
always_crazy = set.intersection(set(ct_entries), set(ct_exits))

# %%
len(always_crazy)
# Out:
# 200

# %% [markdown]
# Decision to drop crazy turnstiles or not:
# * We have 225 turnstiles that can go crazy at the entries, we have 226 turnstiles that can go crazy at the exit. 200 turnstiles are in both sets.
# * total number of turnstiles is 4626
# * the crazy turnstiles make up approximately 5% of the turnstiles (crazy = 251, total = 4626, percentage = 5%)
#
# _We are going the drop the crazy trunstiles_

# %%
# identify crazy turnstiles:
all_crazies = list(set(list(ct_entries) + list(ct_exits)))

# %%
all_crazies
# Out:
# [('J030', 'R005', '00-00-02', '85 ST-FOREST PK'),
#  ('A011', 'R080', '01-00-00', '57 ST-7 AV'),
#  ('E001', 'R368', '00-00-03', '9 AV'),
#  ('R501', 'R054', '00-00-04', '5 AVE'),
#  ('PTH16', 'R550', '01-01-03', 'LACKAWANNA'),
#  ('R148', 'R033', '01-00-01', 'TIMES SQ-42 ST'),
#  ('PTH18', 'R549', '01-00-08', 'NEWARK BM BW'),
#  ('PTH16', 'R550', '01-01-04', 'LACKAWANNA'),
#  ('A025', 'R023', '01-03-02', '34 ST-HERALD SQ'),
#  ('N001', 'R173', '01-06-03', 'INWOOD-207 ST'),
#  ('R194', 'R040', '00-06-01', '231 ST'),
#  ('N039', 'R251', '01-00-01', '96 ST'),
#  ('R527', 'R122', '00-05-01', '90 ST-ELMHURST'),
#  ('N401', 'R360', '00-00-01', '21 ST'),
#  ('R246', 'R177', '00-00-02', '68ST-HUNTER CO'),
#  ('N089', 'R139', '00-03-00', 'CANAL ST'),
#  ('N506', 'R022', '00-03-01', '34 ST-HERALD SQ'),
#  ('R161A', 'R452', '01-06-02', '72 ST'),
#  ('R524', 'R347', '00-05-00', '69 ST'),
#  ('R127', 'R105', '00-00-00', '14 ST'),
#  ('R169', 'R168', '01-07-00', '96 ST'),
#  ('N016A', 'R296', '00-00-01', '163 ST-AMSTERDM'),
#  ('A011', 'R080', '01-00-05', '57 ST-7 AV'),
#  ('JFK03', 'R536', '00-03-00', 'JFK JAMAICA CT1'),
#  ('N536', 'R270', '00-00-01', 'SMITH-9 ST'),
#  ('N544', 'R289', '01-05-00', 'FT HAMILTON PKY'),
#  ('R240', 'R047', '00-03-00', 'GRD CNTRL-42 ST'),
#  ('N137', 'R354', '00-06-00', '104 ST'),
#  ('JFK03', 'R536', '00-00-02', 'JFK JAMAICA CT1'),
#  ('R414', 'R162', '00-03-00', 'ELDER AV'),
#  ('N529', 'R257', '00-00-01', 'EAST BROADWAY'),
#  ('R262', 'R195', '03-00-02', '161/YANKEE STAD'),
#  ('N034', 'R334', '01-06-01', 'CATHEDRAL PKWY'),
#  ('R210', 'R044', '00-03-04', 'BROOKLYN BRIDGE'),
#  ('C019', 'R232', '00-00-01', '45 ST'),
#  ('N543', 'R289', '00-00-00', 'FT HAMILTON PKY'),
#  ('PTH16', 'R550', '01-00-03', 'LACKAWANNA'),
#  ('R304', 'R206', '00-00-00', '125 ST'),
#  ('JFK03', 'R536', '00-03-04', 'JFK JAMAICA CT1'),
#  ('N508', 'R453', '00-00-02', '23 ST'),
#  ('K026', 'R100', '00-00-01', 'METROPOLITAN AV'),
#  ('R632', 'R067', '00-00-02', 'PENNSYLVANIA AV'),
#  ('A046', 'R463', '00-03-00', 'CANAL ST'),
#  ('A037', 'R170', '05-00-00', '14 ST-UNION SQ'),
#  ('R141', 'R031', '00-03-00', '34 ST-PENN STA'),
#  ('JFK03', 'R536', '00-00-05', 'JFK JAMAICA CT1'),
#  ('JFK02', 'R535', '01-00-05', 'HOWARD BCH JFK'),
#  ('B026', 'R230', '00-06-00', 'NECK RD'),
#  ('J034', 'R007', '00-00-02', '104 ST'),
#  ('N067', 'R012', '00-03-00', '34 ST-PENN STA'),
#  ('JFK03', 'R536', '00-00-04', 'JFK JAMAICA CT1'),
#  ('PTH07', 'R550', '00-01-02', 'CITY / BUS'),
#  ('R633', 'R068', '00-00-00', 'VAN SICLEN AV'),
#  ('R526', 'R096', '00-05-03', '82 ST-JACKSON H'),
#  ('N401', 'R360', '00-00-00', '21 ST'),
#  ('JFK03', 'R536', '00-03-01', 'JFK JAMAICA CT1'),
#  ('PTH01', 'R549', '00-00-0A', 'NEWARK HW BMEBE'),
#  ('PTH18', 'R549', '01-00-06', 'NEWARK BM BW'),
#  ('A010', 'R080', '00-00-05', '57 ST-7 AV'),
#  ('R232A', 'R176', '03-06-01', '33 ST'),
#  ('N103', 'R127', '00-02-00', 'JAY ST-METROTEC'),
#  ('N001', 'R173', '01-05-00', 'INWOOD-207 ST'),
#  ('R238A', 'R046', '02-00-03', 'GRD CNTRL-42 ST'),
#  ('N080', 'R138', '00-00-00', 'W 4 ST-WASH SQ'),
#  ('B032', 'R264', '00-00-00', 'OCEAN PKWY'),
#  ('JFK03', 'R536', '00-03-03', 'JFK JAMAICA CT1'),
#  ('B020', 'R263', '00-06-05', 'AVENUE H'),
#  ('N329', 'R201', '00-00-01', 'WOODHAVEN BLVD'),
#  ('PTH07', 'R550', '00-00-00', 'CITY / BUS'),
#  ('R310', 'R053', '01-00-02', '3 AV-149 ST'),
#  ('N312', 'R339', '00-06-00', '36 ST'),
#  ('A016', 'R081', '03-06-01', '49 ST'),
#  ('H023', 'R236', '00-06-00', 'DEKALB AV'),
#  ('R418', 'R106', '00-03-00', 'CASTLE HILL AV'),
#  ('N342', 'R019', '01-03-02', 'JAMAICA 179 ST'),
#  ('R637', 'R451', '00-00-01', 'WINTHROP ST'),
#  ('PTH18', 'R549', '01-01-01', 'NEWARK BM BW'),
#  ('JFK02', 'R535', '01-00-01', 'HOWARD BCH JFK'),
#  ('N126', 'R441', '00-00-01', 'VAN SICLEN AVE'),
#  ('N111', 'R284', '00-06-01', 'CLINTON-WASH AV'),
#  ('A011', 'R080', '01-00-04', '57 ST-7 AV'),
#  ('H008', 'R248', '01-00-00', '1 AV'),
#  ('N520', 'R240', '00-00-02', 'GRAND ST'),
#  ('R305', 'R206', '01-00-00', '125 ST'),
#  ('N327', 'R254', '00-06-01', 'GRAND-NEWTOWN'),
#  ('H014', 'R249', '00-00-01', 'GRAHAM AV'),
#  ('JFK03', 'R536', '00-00-01', 'JFK JAMAICA CT1'),
#  ('PTH01', 'R549', '00-00-02', 'NEWARK HW BMEBE'),
#  ('R243', 'R049', '00-03-04', '51 ST'),
#  ('N203', 'R195', '00-03-04', '161/YANKEE STAD'),
#  ('C009', 'R057', '03-05-00', 'ATL AV-BARCLAY'),
#  ('R636', 'R209', '00-00-02', 'STERLING ST'),
#  ('R519', 'R223', '00-00-01', '46 ST BLISS ST'),
#  ('R148', 'R033', '01-06-00', 'TIMES SQ-42 ST'),
#  ('N215', 'R237', '00-00-01', '182-183 STS'),
#  ('N114', 'R297', '01-00-03', 'FRANKLIN AV'),
#  ('PTH06', 'R546', '00-00-00', 'PAVONIA/NEWPORT'),
#  ('R204', 'R043', '02-05-00', 'WALL ST'),
#  ('R139', 'R031', '04-06-00', '34 ST-PENN STA'),
#  ('R186', 'R036', '00-00-00', 'DYCKMAN ST'),
#  ('R423', 'R429', '00-03-00', 'PELHAM BAY PARK'),
#  ('PTH02', 'R544', '00-04-00', 'HARRISON'),
#  ('N103', 'R127', '00-03-01', 'JAY ST-METROTEC'),
#  ('R305', 'R206', '01-00-02', '125 ST'),
#  ('H009', 'R235', '00-06-01', 'BEDFORD AV'),
#  ('N324', 'R018', '00-00-04', 'JKSN HT-ROOSVLT'),
#  ('PTH11', 'R545', '00-00-01', '14TH STREET'),
#  ('N221', 'R155', '00-00-02', 'KINGSBRIDGE RD'),
#  ('R175', 'R169', '01-00-04', '137 ST CITY COL'),
#  ('JFK01', 'R535', '00-00-01', 'HOWARD BCH JFK'),
#  ('N333A', 'R141', '00-00-03', 'FOREST HILLS 71'),
#  ('R258', 'R132', '00-03-02', '125 ST'),
#  ('PTH18', 'R549', '01-02-00', 'NEWARK BM BW'),
#  ('R206', 'R014', '02-03-01', 'FULTON ST'),
#  ('PTH20', 'R549', '03-01-04', 'NEWARK HM HE'),
#  ('R501', 'R054', '00-06-01', '5 AVE'),
#  ('PTH12', 'R542', '00-04-01', 'TWENTY THIRD ST'),
#  ('R256', 'R182', '00-00-02', '116 ST'),
#  ('N086', 'R282', '00-00-01', 'SPRING ST'),
#  ('JFK02', 'R535', '01-00-03', 'HOWARD BCH JFK'),
#  ('R415', 'R120', '00-05-01', 'MORISN AV/SNDVW'),
#  ('H009', 'R235', '00-06-03', 'BEDFORD AV'),
#  ('N137', 'R354', '00-06-01', '104 ST'),
#  ('PTH16', 'R550', '01-00-06', 'LACKAWANNA'),
#  ('R291', 'R183', '00-00-01', 'BEDFORD PK BLVD'),
#  ('JFK03', 'R536', '00-00-03', 'JFK JAMAICA CT1'),
#  ('PTH12', 'R542', '00-00-00', 'TWENTY THIRD ST'),
#  ('R550', 'R072', '00-03-0A', '34 ST-HUDSON YD'),
#  ('N128', 'R200', '00-00-05', 'EUCLID AV'),
#  ('N528', 'R257', '01-05-00', 'EAST BROADWAY'),
#  ('PTH13', 'R541', '00-00-00', 'THIRTY ST'),
#  ('B025', 'R150', '00-05-01', 'AVENUE U'),
#  ('N063A', 'R011', '00-00-05', '42 ST-PORT AUTH'),
#  ('R333', 'R366', '00-00-01', '225 ST'),
#  ('H003', 'R163', '01-00-02', '6 AV'),
#  ('PTH19', 'R549', '02-02-01', 'NEWARK C'),
#  ('R527', 'R122', '00-05-00', '90 ST-ELMHURST'),
#  ('JFK03', 'R536', '00-03-02', 'JFK JAMAICA CT1'),
#  ('PTH04', 'R551', '00-00-03', 'GROVE STREET'),
#  ('N606', 'R025', '00-00-01', 'JAMAICA CENTER'),
#  ('R641', 'R210', '00-06-00', 'BEVERLY RD'),
#  ('JFK01', 'R535', '00-00-02', 'HOWARD BCH JFK'),
#  ('R242', 'R049', '01-00-02', '51 ST'),
#  ('R621', 'R060', '00-03-01', 'EASTN PKWY-MUSM'),
#  ('PTH13', 'R541', '00-04-08', 'THIRTY ST'),
#  ('PTH16', 'R550', '01-02-03', 'LACKAWANNA'),
#  ('H009', 'R235', '00-06-05', 'BEDFORD AV'),
#  ('B021', 'R228', '00-03-02', 'AVENUE J'),
#  ('N057', 'R188', '00-00-00', '50 ST'),
#  ('N600', 'R302', '00-06-03', '57 ST'),
#  ('PTH08', 'R540', '00-04-03', 'PATH WTC'),
#  ('N029', 'R333', '01-00-02', '116 ST'),
#  ('R192', 'R039', '00-00-01', 'MARBLE HILL-225'),
#  ('R401', 'R445', '00-00-01', '3 AV 138 ST'),
#  ('N134', 'R385', '00-00-01', 'ROCKAWAY BLVD'),
#  ('PTH16', 'R550', '01-01-06', 'LACKAWANNA'),
#  ('R251', 'R144', '00-03-01', '96 ST'),
#  ('A011', 'R080', '01-00-03', '57 ST-7 AV'),
#  ('PTH20', 'R549', '03-01-06', 'NEWARK HM HE'),
#  ('R526', 'R096', '00-05-02', '82 ST-JACKSON H'),
#  ('N208', 'R443', '01-00-01', '170 ST'),
#  ('PTH19', 'R549', '02-00-01', 'NEWARK C'),
#  ('R646', 'R110', '01-00-01', 'FLATBUSH AV-B.C'),
#  ('PTH04', 'R551', '00-01-02', 'GROVE STREET'),
#  ('R227', 'R131', '00-00-00', '23 ST'),
#  ('R130', 'R321', '01-00-02', '18 ST'),
#  ('PTH02', 'R544', '00-00-06', 'HARRISON'),
#  ('N203', 'R195', '00-00-01', '161/YANKEE STAD'),
#  ('A049', 'R088', '02-05-00', 'CORTLANDT ST'),
#  ('B021', 'R228', '00-03-01', 'AVENUE J'),
#  ('N062', 'R011', '01-00-01', '42 ST-PORT AUTH'),
#  ('R183', 'R260', '00-00-02', '181 ST'),
#  ('PTH04', 'R551', '00-01-00', 'GROVE STREET'),
#  ('B022', 'R229', '00-05-00', 'AVENUE M'),
#  ('PTH16', 'R550', '01-01-01', 'LACKAWANNA'),
#  ('R524', 'R347', '00-05-01', '69 ST'),
#  ('R417', 'R222', '00-00-03', 'PARKCHESTER'),
#  ('B021', 'R228', '00-03-00', 'AVENUE J'),
#  ('N120A', 'R153', '01-06-00', 'UTICA AV'),
#  ('R622', 'R123', '00-00-00', 'FRANKLIN AV'),
#  ('R179', 'R193', '01-00-01', '157 ST'),
#  ('R629', 'R065', '00-03-02', 'ROCKAWAY AV'),
#  ('PTH01', 'R549', '00-01-03', 'NEWARK HW BMEBE'),
#  ('N502', 'R021', '01-00-00', '42 ST-BRYANT PK'),
#  ('PTH12', 'R542', '00-04-03', 'TWENTY THIRD ST'),
#  ('N602', 'R259', '00-05-01', 'ROOSEVELT ISLND'),
#  ('PTH13', 'R541', '00-04-00', 'THIRTY ST'),
#  ('R414', 'R162', '00-00-01', 'ELDER AV'),
#  ('PTH06', 'R546', '00-00-01', 'PAVONIA/NEWPORT'),
#  ('R527', 'R122', '00-00-01', '90 ST-ELMHURST'),
#  ('PTH07', 'R550', '00-01-07', 'CITY / BUS'),
#  ('N063A', 'R011', '00-00-08', '42 ST-PORT AUTH'),
#  ('PTH13', 'R541', '00-00-03', 'THIRTY ST'),
#  ('PTH19', 'R549', '02-02-02', 'NEWARK C'),
#  ('A066', 'R118', '00-00-00', 'CANAL ST'),
#  ('R322', 'R386', '00-00-02', '174 ST'),
#  ('R245', 'R051', '00-03-02', '59 ST'),
#  ('N551', 'R421', '00-00-00', 'AVENUE I'),
#  ('N067', 'R012', '00-03-02', '34 ST-PENN STA'),
#  ('C019', 'R232', '00-00-02', '45 ST'),
#  ('N089', 'R139', '00-03-01', 'CANAL ST'),
#  ('PTH18', 'R549', '01-00-07', 'NEWARK BM BW'),
#  ('R163', 'R166', '01-00-00', '79 ST'),
#  ('B024', 'R211', '00-05-01', 'KINGS HWY'),
#  ('R327', 'R361', '01-05-00', 'PELHAM PKWY'),
#  ('R249', 'R179', '01-00-04', '86 ST'),
#  ('R625', 'R062', '01-00-00', 'CROWN HTS-UTICA'),
#  ('PTH10', 'R547', '00-00-03', '9TH STREET'),
#  ('R532H', 'R328', '02-03-04', 'METS-WILLETS PT'),
#  ('D002', 'R390', '00-03-00', '8 AV'),
#  ('R126', 'R189', '01-00-02', 'CHRISTOPHER ST'),
#  ('JFK02', 'R535', '01-00-06', 'HOWARD BCH JFK'),
#  ('N539A', 'R288', '00-06-00', '7 AV'),
#  ('JFK02', 'R535', '01-00-04', 'HOWARD BCH JFK'),
#  ('PTH07', 'R550', '00-02-02', 'CITY / BUS'),
#  ('R158', 'R084', '00-06-03', '59 ST COLUMBUS'),
#  ('N128', 'R200', '00-00-02', 'EUCLID AV'),
#  ('N532', 'R129', '00-00-02', 'BERGEN ST'),
#  ('N605', 'R024', '00-06-01', 'SUTPHIN-ARCHER'),
#  ('R550', 'R072', '00-03-09', '34 ST-HUDSON YD'),
#  ('N078', 'R175', '01-00-01', '14 ST'),
#  ('N601', 'R319', '00-00-01', 'LEXINGTON AV/63'),
#  ('R306', 'R207', '00-00-01', '135 ST'),
#  ('N543', 'R289', '00-00-01', 'FT HAMILTON PKY'),
#  ('A014', 'R081', '02-06-01', '49 ST'),
#  ('N305', 'R017', '01-03-04', 'LEXINGTON AV/53'),
#  ('R206', 'R014', '02-05-01', 'FULTON ST'),
#  ('N543', 'R289', '00-00-02', 'FT HAMILTON PKY'),
#  ('JFK02', 'R535', '01-00-02', 'HOWARD BCH JFK'),
#  ('PTH05', 'R543', '00-01-05', 'EXCHANGE PLACE'),
#  ('H041', 'R152', '00-06-00', 'CANARSIE-ROCKAW'),
#  ('R550', 'R072', '00-03-00', '34 ST-HUDSON YD'),
#  ('N083', 'R138', '01-00-01', 'W 4 ST-WASH SQ'),
#  ('J034', 'R007', '00-00-01', '104 ST'),
#  ('R258', 'R132', '00-00-03', '125 ST'),
#  ('PTH02', 'R544', '00-00-01', 'HARRISON'),
#  ('JFK01', 'R535', '00-00-03', 'HOWARD BCH JFK'),
#  ('B017', 'R262', '00-00-02', 'BEVERLEY ROAD'),
#  ('A069', 'R044', '01-06-01', 'CHAMBERS ST'),
#  ('N208', 'R443', '01-05-01', '170 ST'),
#  ('N539A', 'R288', '00-06-01', '7 AV'),
#  ('R417', 'R222', '00-00-01', 'PARKCHESTER'),
#  ('B028', 'R136', '01-00-01', 'SHEEPSHEAD BAY'),
#  ('N213', 'R154', '00-00-05', 'TREMONT AV'),
#  ('PTH04', 'R551', '00-01-01', 'GROVE STREET'),
#  ('R647', 'R110', '02-05-01', 'FLATBUSH AV-B.C'),
#  ('N063A', 'R011', '00-00-04', '42 ST-PORT AUTH'),
#  ('N333A', 'R141', '00-00-01', 'FOREST HILLS 71'),
#  ('R192', 'R039', '00-06-00', 'MARBLE HILL-225'),
#  ('N203', 'R195', '00-03-03', '161/YANKEE STAD'),
#  ('PTH17', 'R541', '01-01-01', 'THIRTY THIRD ST')]

# %%
stations_with_ct = []
for ts in all_crazies:
    stations_with_ct.append(ts[3])

# %%
len(set(stations_with_ct))
# Out:
# 142

# %% [markdown]
# There are 142 stations where at a certain point there was a crazy turnstile, out of a total of 376 stations.

# %%
# total number of stations:
len(data.STATION.unique())
# Out:
# 376

# %% [markdown]
# We decided to drop the crazy turnstiles altogether, since at first glance they are well spread among the stations.
# Future work might include determining distribution of crazy turnstiles in trainstations, to better understand the impact of dropping these data. There might be higher concentration of crazy turnstiles in certain stations. For this to be possible, it is necessary to determine the number of turnstiles in each station, determine how many of these are faulty, and make sure that dropping data from crazy turnstiles has a uniform impast on the data from each station.

# %%
data_daily = data_daily_entries
data_daily
# Out:
#           C/A  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 1        A002  R051  02-00-00          59 ST  05/29/2016  5683957  05/28/2016
# 2        A002  R051  02-00-00          59 ST  05/30/2016  5684749  05/29/2016
# 3        A002  R051  02-00-00          59 ST  05/31/2016  5685506  05/30/2016
# 4        A002  R051  02-00-00          59 ST  06/01/2016  5687282  05/31/2016
# 5        A002  R051  02-00-00          59 ST  06/02/2016  5689073  06/01/2016
# 6        A002  R051  02-00-00          59 ST  06/03/2016  5690839  06/02/2016
# 7        A002  R051  02-00-00          59 ST  06/04/2016  5692587  06/03/2016
# 8        A002  R051  02-00-00          59 ST  06/05/2016  5693604  06/04/2016
# 9        A002  R051  02-00-00          59 ST  06/06/2016  5694361  06/05/2016
# 10       A002  R051  02-00-00          59 ST  06/07/2016  5696129  06/06/2016
# 11       A002  R051  02-00-00          59 ST  06/08/2016  5697918  06/07/2016
# 12       A002  R051  02-00-00          59 ST  06/09/2016  5699775  06/08/2016
# 13       A002  R051  02-00-00          59 ST  06/10/2016  5701611  06/09/2016
# 14       A002  R051  02-00-00          59 ST  06/11/2016  5703420  06/10/2016
# 15       A002  R051  02-00-00          59 ST  06/12/2016  5704439  06/11/2016
# 16       A002  R051  02-00-00          59 ST  06/13/2016  5704958  06/12/2016
# 17       A002  R051  02-00-00          59 ST  06/14/2016  5704958  06/13/2016
# 18       A002  R051  02-00-00          59 ST  06/15/2016  5704958  06/14/2016
# 19       A002  R051  02-00-00          59 ST  06/16/2016  5704958  06/15/2016
# 20       A002  R051  02-00-00          59 ST  06/18/2016  5704958  06/16/2016
# 21       A002  R051  02-00-00          59 ST  06/19/2016  5704958  06/18/2016
# 22       A002  R051  02-00-00          59 ST  06/20/2016  5705337  06/19/2016
# 23       A002  R051  02-00-00          59 ST  06/21/2016  5706844  06/20/2016
# 24       A002  R051  02-00-00          59 ST  06/22/2016  5708543  06/21/2016
# 25       A002  R051  02-00-00          59 ST  06/23/2016  5710209  06/22/2016
# 26       A002  R051  02-00-00          59 ST  06/24/2016  5711852  06/23/2016
# 27       A002  R051  02-00-00          59 ST  06/25/2016  5713268  06/24/2016
# 28       A002  R051  02-00-00          59 ST  06/26/2016  5714130  06/25/2016
# 29       A002  R051  02-00-00          59 ST  06/27/2016  5714706  06/26/2016
# 30       A002  R051  02-00-00          59 ST  06/28/2016  5716372  06/27/2016
# ...       ...   ...       ...            ...         ...      ...         ...
# 542963  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/25/2016     5554  08/24/2016
# 542964  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/26/2016     5554  08/25/2016
# 542965  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/27/2016     5554  08/26/2016
# 542966  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/28/2016     5554  08/27/2016
# 542967  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/29/2016     5554  08/28/2016
# 542968  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/30/2016     5554  08/29/2016
# 542969  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/31/2016     5554  08/30/2016
# 542970  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/01/2016     5554  08/31/2016
# 542971  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/02/2016     5554  09/01/2016
# 542972  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/03/2016     5554  09/02/2016
# 542973  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/04/2016     5554  09/03/2016
# 542974  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/05/2016     5554  09/04/2016
# 542975  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/06/2016     5554  09/05/2016
# 542976  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/07/2016     5554  09/06/2016
# 542977  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/08/2016     5554  09/07/2016
# 542978  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/09/2016     5554  09/08/2016
# 542979  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/10/2016     5554  09/09/2016
# 542980  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/11/2016     5554  09/10/2016
# 542981  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/12/2016     5554  09/11/2016
# 542982  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/13/2016     5554  09/12/2016
# 542983  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/14/2016     5554  09/13/2016
# 542984  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/15/2016     5554  09/14/2016
# 542985  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/16/2016     5554  09/15/2016
# 542986  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/17/2016     5554  09/16/2016
# 542987  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/18/2016     5554  09/17/2016
# 542988  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/19/2016     5554  09/18/2016
# 542989  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/20/2016     5554  09/19/2016
# 542990  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/21/2016     5554  09/20/2016
# 542991  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/22/2016     5554  09/21/2016
# 542992  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/23/2016     5554  09/22/2016
#
#         PREV_ENTRIES    EXITS  PREV_EXITS
# 1          5682962.0  1924599   1924340.0
# 2          5683957.0  1924791   1924599.0
# 3          5684749.0  1925050   1924791.0
# 4          5685506.0  1925601   1925050.0
# 5          5687282.0  1926208   1925601.0
# 6          5689073.0  1926746   1926208.0
# 7          5690839.0  1927326   1926746.0
# 8          5692587.0  1927651   1927326.0
# 9          5693604.0  1927909   1927651.0
# 10         5694361.0  1928509   1927909.0
# 11         5696129.0  1929120   1928509.0
# 12         5697918.0  1929754   1929120.0
# 13         5699775.0  1930294   1929754.0
# 14         5701611.0  1930887   1930294.0
# 15         5703420.0  1931216   1930887.0
# 16         5704439.0  1931431   1931216.0
# 17         5704958.0  1932103   1931431.0
# 18         5704958.0  1932795   1932103.0
# 19         5704958.0  1933437   1932795.0
# 20         5704958.0  1934814   1933437.0
# 21         5704958.0  1935168   1934814.0
# 22         5704958.0  1935508   1935168.0
# 23         5705337.0  1936061   1935508.0
# 24         5706844.0  1936656   1936061.0
# 25         5708543.0  1937232   1936656.0
# 26         5710209.0  1937825   1937232.0
# 27         5711852.0  1938354   1937825.0
# 28         5713268.0  1938649   1938354.0
# 29         5714130.0  1938907   1938649.0
# 30         5714706.0  1939498   1938907.0
# ...              ...      ...         ...
# 542963        5554.0      257       257.0
# 542964        5554.0      257       257.0
# 542965        5554.0      257       257.0
# 542966        5554.0      257       257.0
# 542967        5554.0      257       257.0
# 542968        5554.0      257       257.0
# 542969        5554.0      257       257.0
# 542970        5554.0      259       257.0
# 542971        5554.0      259       259.0
# 542972        5554.0      259       259.0
# 542973        5554.0      261       259.0
# 542974        5554.0      261       261.0
# 542975        5554.0      262       261.0
# 542976        5554.0      262       262.0
# 542977        5554.0      262       262.0
# 542978        5554.0      271       262.0
# 542979        5554.0      271       271.0
# 542980        5554.0      271       271.0
# 542981        5554.0      271       271.0
# 542982        5554.0      271       271.0
# 542983        5554.0      271       271.0
# 542984        5554.0      271       271.0
# 542985        5554.0      271       271.0
# 542986        5554.0      271       271.0
# 542987        5554.0      271       271.0
# 542988        5554.0      271       271.0
# 542989        5554.0      271       271.0
# 542990        5554.0      271       271.0
# 542991        5554.0      271       271.0
# 542992        5554.0      271       271.0
#
# [538364 rows x 10 columns]

# %%
# drop the crazy turnstiles:
for ts in all_crazies:
    mask = ((data_daily["C/A"] == ts[0]) & (data_daily["UNIT"] == ts[1]) & 
            (data_daily["SCP"] == ts[2]) & (data_daily["STATION"] == ts[3]))
    data_daily.drop(data_daily[mask].index, inplace=True)

# %%
data_daily[(data_daily['C/A']=='A002') & (data_daily.SCP == '02-00-00')]
# Out:
#       C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1    A002  R051  02-00-00   59 ST  05/29/2016  5683957  05/28/2016
# 2    A002  R051  02-00-00   59 ST  05/30/2016  5684749  05/29/2016
# 3    A002  R051  02-00-00   59 ST  05/31/2016  5685506  05/30/2016
# 4    A002  R051  02-00-00   59 ST  06/01/2016  5687282  05/31/2016
# 5    A002  R051  02-00-00   59 ST  06/02/2016  5689073  06/01/2016
# 6    A002  R051  02-00-00   59 ST  06/03/2016  5690839  06/02/2016
# 7    A002  R051  02-00-00   59 ST  06/04/2016  5692587  06/03/2016
# 8    A002  R051  02-00-00   59 ST  06/05/2016  5693604  06/04/2016
# 9    A002  R051  02-00-00   59 ST  06/06/2016  5694361  06/05/2016
# 10   A002  R051  02-00-00   59 ST  06/07/2016  5696129  06/06/2016
# 11   A002  R051  02-00-00   59 ST  06/08/2016  5697918  06/07/2016
# 12   A002  R051  02-00-00   59 ST  06/09/2016  5699775  06/08/2016
# 13   A002  R051  02-00-00   59 ST  06/10/2016  5701611  06/09/2016
# 14   A002  R051  02-00-00   59 ST  06/11/2016  5703420  06/10/2016
# 15   A002  R051  02-00-00   59 ST  06/12/2016  5704439  06/11/2016
# 16   A002  R051  02-00-00   59 ST  06/13/2016  5704958  06/12/2016
# 17   A002  R051  02-00-00   59 ST  06/14/2016  5704958  06/13/2016
# 18   A002  R051  02-00-00   59 ST  06/15/2016  5704958  06/14/2016
# 19   A002  R051  02-00-00   59 ST  06/16/2016  5704958  06/15/2016
# 20   A002  R051  02-00-00   59 ST  06/18/2016  5704958  06/16/2016
# 21   A002  R051  02-00-00   59 ST  06/19/2016  5704958  06/18/2016
# 22   A002  R051  02-00-00   59 ST  06/20/2016  5705337  06/19/2016
# 23   A002  R051  02-00-00   59 ST  06/21/2016  5706844  06/20/2016
# 24   A002  R051  02-00-00   59 ST  06/22/2016  5708543  06/21/2016
# 25   A002  R051  02-00-00   59 ST  06/23/2016  5710209  06/22/2016
# 26   A002  R051  02-00-00   59 ST  06/24/2016  5711852  06/23/2016
# 27   A002  R051  02-00-00   59 ST  06/25/2016  5713268  06/24/2016
# 28   A002  R051  02-00-00   59 ST  06/26/2016  5714130  06/25/2016
# 29   A002  R051  02-00-00   59 ST  06/27/2016  5714706  06/26/2016
# 30   A002  R051  02-00-00   59 ST  06/28/2016  5716372  06/27/2016
# ..    ...   ...       ...     ...         ...      ...         ...
# 88   A002  R051  02-00-00   59 ST  08/25/2016  5796665  08/24/2016
# 89   A002  R051  02-00-00   59 ST  08/26/2016  5797976  08/25/2016
# 90   A002  R051  02-00-00   59 ST  08/27/2016  5799442  08/26/2016
# 91   A002  R051  02-00-00   59 ST  08/28/2016  5800252  08/27/2016
# 92   A002  R051  02-00-00   59 ST  08/29/2016  5800934  08/28/2016
# 93   A002  R051  02-00-00   59 ST  08/30/2016  5802514  08/29/2016
# 94   A002  R051  02-00-00   59 ST  08/31/2016  5804071  08/30/2016
# 95   A002  R051  02-00-00   59 ST  09/01/2016  5805638  08/31/2016
# 96   A002  R051  02-00-00   59 ST  09/02/2016  5807232  09/01/2016
# 97   A002  R051  02-00-00   59 ST  09/03/2016  5808846  09/02/2016
# 98   A002  R051  02-00-00   59 ST  09/04/2016  5809667  09/03/2016
# 99   A002  R051  02-00-00   59 ST  09/05/2016  5810301  09/04/2016
# 100  A002  R051  02-00-00   59 ST  09/06/2016  5810983  09/05/2016
# 101  A002  R051  02-00-00   59 ST  09/07/2016  5812369  09/06/2016
# 102  A002  R051  02-00-00   59 ST  09/08/2016  5814038  09/07/2016
# 103  A002  R051  02-00-00   59 ST  09/09/2016  5815801  09/08/2016
# 104  A002  R051  02-00-00   59 ST  09/10/2016  5817505  09/09/2016
# 105  A002  R051  02-00-00   59 ST  09/11/2016  5818403  09/10/2016
# 106  A002  R051  02-00-00   59 ST  09/12/2016  5819116  09/11/2016
# 107  A002  R051  02-00-00   59 ST  09/13/2016  5820776  09/12/2016
# 108  A002  R051  02-00-00   59 ST  09/14/2016  5822527  09/13/2016
# 109  A002  R051  02-00-00   59 ST  09/15/2016  5824271  09/14/2016
# 110  A002  R051  02-00-00   59 ST  09/16/2016  5826092  09/15/2016
# 111  A002  R051  02-00-00   59 ST  09/17/2016  5827822  09/16/2016
# 112  A002  R051  02-00-00   59 ST  09/18/2016  5828891  09/17/2016
# 113  A002  R051  02-00-00   59 ST  09/19/2016  5829595  09/18/2016
# 114  A002  R051  02-00-00   59 ST  09/20/2016  5831286  09/19/2016
# 115  A002  R051  02-00-00   59 ST  09/21/2016  5833069  09/20/2016
# 116  A002  R051  02-00-00   59 ST  09/22/2016  5834901  09/21/2016
# 117  A002  R051  02-00-00   59 ST  09/23/2016  5836697  09/22/2016
#
#      PREV_ENTRIES    EXITS  PREV_EXITS
# 1       5682962.0  1924599   1924340.0
# 2       5683957.0  1924791   1924599.0
# 3       5684749.0  1925050   1924791.0
# 4       5685506.0  1925601   1925050.0
# 5       5687282.0  1926208   1925601.0
# 6       5689073.0  1926746   1926208.0
# 7       5690839.0  1927326   1926746.0
# 8       5692587.0  1927651   1927326.0
# 9       5693604.0  1927909   1927651.0
# 10      5694361.0  1928509   1927909.0
# 11      5696129.0  1929120   1928509.0
# 12      5697918.0  1929754   1929120.0
# 13      5699775.0  1930294   1929754.0
# 14      5701611.0  1930887   1930294.0
# 15      5703420.0  1931216   1930887.0
# 16      5704439.0  1931431   1931216.0
# 17      5704958.0  1932103   1931431.0
# 18      5704958.0  1932795   1932103.0
# 19      5704958.0  1933437   1932795.0
# 20      5704958.0  1934814   1933437.0
# 21      5704958.0  1935168   1934814.0
# 22      5704958.0  1935508   1935168.0
# 23      5705337.0  1936061   1935508.0
# 24      5706844.0  1936656   1936061.0
# 25      5708543.0  1937232   1936656.0
# 26      5710209.0  1937825   1937232.0
# 27      5711852.0  1938354   1937825.0
# 28      5713268.0  1938649   1938354.0
# 29      5714130.0  1938907   1938649.0
# 30      5714706.0  1939498   1938907.0
# ..            ...      ...         ...
# 88      5795047.0  1965027   1964497.0
# 89      5796665.0  1965560   1965027.0
# 90      5797976.0  1966041   1965560.0
# 91      5799442.0  1966295   1966041.0
# 92      5800252.0  1966546   1966295.0
# 93      5800934.0  1967057   1966546.0
# 94      5802514.0  1967579   1967057.0
# 95      5804071.0  1968054   1967579.0
# 96      5805638.0  1968566   1968054.0
# 97      5807232.0  1968971   1968566.0
# 98      5808846.0  1969229   1968971.0
# 99      5809667.0  1969417   1969229.0
# 100     5810301.0  1969652   1969417.0
# 101     5810983.0  1970207   1969652.0
# 102     5812369.0  1970772   1970207.0
# 103     5814038.0  1971329   1970772.0
# 104     5815801.0  1971936   1971329.0
# 105     5817505.0  1972285   1971936.0
# 106     5818403.0  1972514   1972285.0
# 107     5819116.0  1973081   1972514.0
# 108     5820776.0  1973687   1973081.0
# 109     5822527.0  1974282   1973687.0
# 110     5824271.0  1974883   1974282.0
# 111     5826092.0  1975506   1974883.0
# 112     5827822.0  1975837   1975506.0
# 113     5828891.0  1976100   1975837.0
# 114     5829595.0  1976662   1976100.0
# 115     5831286.0  1977287   1976662.0
# 116     5833069.0  1977936   1977287.0
# 117     5834901.0  1978573   1977936.0
#
# [117 rows x 10 columns]

# %%
data_daily['SALDO_ENTRIES'] = data_daily['ENTRIES']-data_daily['PREV_ENTRIES']
data_daily['SALDO_EXITS'] = data_daily['EXITS']-data_daily['PREV_EXITS']
data_daily['TRANSITING'] = data_daily['SALDO_ENTRIES'] + data_daily['SALDO_EXITS']

# %%
data_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/29/2016  5683957  05/28/2016
# 2  A002  R051  02-00-00   59 ST  05/30/2016  5684749  05/29/2016
# 3  A002  R051  02-00-00   59 ST  05/31/2016  5685506  05/30/2016
# 4  A002  R051  02-00-00   59 ST  06/01/2016  5687282  05/31/2016
# 5  A002  R051  02-00-00   59 ST  06/02/2016  5689073  06/01/2016
#
#    PREV_ENTRIES    EXITS  PREV_EXITS  SALDO_ENTRIES  SALDO_EXITS  TRANSITING
# 1     5682962.0  1924599   1924340.0          995.0        259.0      1254.0
# 2     5683957.0  1924791   1924599.0          792.0        192.0       984.0
# 3     5684749.0  1925050   1924791.0          757.0        259.0      1016.0
# 4     5685506.0  1925601   1925050.0         1776.0        551.0      2327.0
# 5     5687282.0  1926208   1925601.0         1791.0        607.0      2398.0

# %% [markdown]
# data_daily is a df that has column 'TRANSITING' which contains the number of people going through a turnstile on a certain day

# %% [markdown]
# We still get some abnormal datapoints. We will just cut off what doesn't make sense.

# %%
data_daily.SALDO_ENTRIES.sort_values(ascending=False).head(100)
# Out:
# 165688    1.905098e+09
# 205854    3.342257e+08
# 76276     1.509941e+08
# 456164    1.174400e+08
# 397483    1.174397e+08
# 48995     1.006632e+08
# 197074    6.710886e+07
# 480087    6.697559e+07
# 55185     6.633143e+07
# 288295    6.598917e+07
# 8717      6.547201e+07
# 85290     6.047959e+07
# 157946    4.920656e+07
# 412660    1.677688e+07
# 142480    2.402833e+06
# 161062    1.293359e+06
# 472342    3.931740e+05
# 196955    2.618530e+05
# 177356    2.615710e+05
# 69174     5.407000e+04
# 278101    1.629700e+04
# 380408    1.413200e+04
# 157987    1.328600e+04
# 161527    1.314400e+04
# 115050    1.251800e+04
# 380523    1.184000e+04
# 372975    1.108900e+04
# 380293    1.053600e+04
# 277189    1.043200e+04
# 286086    1.006000e+04
#               ...
# 416516    8.816000e+03
# 416944    8.773000e+03
# 419679    8.768000e+03
# 416943    8.762000e+03
# 416951    8.727000e+03
# 416558    8.707000e+03
# 416556    8.705000e+03
# 419631    8.687000e+03
# 416508    8.676000e+03
# 416950    8.649000e+03
# 419678    8.632000e+03
# 416947    8.630000e+03
# 419574    8.627000e+03
# 426119    8.583000e+03
# 265864    8.567000e+03
# 132588    8.567000e+03
# 416942    8.566000e+03
# 404129    8.547000e+03
# 433482    8.540000e+03
# 416565    8.539000e+03
# 419672    8.507000e+03
# 277417    8.506000e+03
# 416600    8.505000e+03
# 300775    8.502000e+03
# 452353    8.471000e+03
# 416922    8.470000e+03
# 416557    8.464000e+03
# 416517    8.454000e+03
# 419673    8.447000e+03
# 419680    8.443000e+03
# Name: SALDO_ENTRIES, dtype: float64

# %%
data_daily = data_daily[data_daily['SALDO_ENTRIES'] < 10000]

# %%
data_daily.to_csv('/Users/aleksandra/ds/metis/Project-Benson/Data/data_daily.csv')

# %% [markdown]
# Next: make a df called 'stations_transit' that has a column of stations and a column of dates and a column of people transiting.

# %%
list_of_stations =list(data_daily.STATION.unique())

# %%
list_of_stations
# Out:
# ['59 ST',
#  '5 AV/59 ST',
#  '57 ST-7 AV',
#  '49 ST',
#  'TIMES SQ-42 ST',
#  '34 ST-HERALD SQ',
#  '28 ST',
#  '23 ST',
#  '14 ST-UNION SQ',
#  '8 ST-NYU',
#  'PRINCE ST',
#  'CANAL ST',
#  'CITY HALL',
#  'CORTLANDT ST',
#  'RECTOR ST',
#  'WHITEHALL S-FRY',
#  'DELANCEY/ESSEX',
#  'BOWERY',
#  'CHAMBERS ST',
#  'FULTON ST',
#  'BROAD ST',
#  '7 AV',
#  'PARK PLACE',
#  'BOTANIC GARDEN',
#  'PROSPECT PARK',
#  'PARKSIDE AV',
#  'CHURCH AV',
#  'BEVERLEY ROAD',
#  'CORTELYOU RD',
#  'NEWKIRK PLAZA',
#  'AVENUE H',
#  'AVENUE J',
#  'AVENUE M',
#  'KINGS HWY',
#  'AVENUE U',
#  'NECK RD',
#  'SHEEPSHEAD BAY',
#  'BRIGHTON BEACH',
#  'OCEAN PKWY',
#  'BOROUGH HALL',
#  'JAY ST-METROTEC',
#  'DEKALB AV',
#  'ATL AV-BARCLAY',
#  'UNION ST',
#  '4AV-9 ST',
#  'PROSPECT AV',
#  '25 ST',
#  '36 ST',
#  '45 ST',
#  '53 ST',
#  'BAY RIDGE AV',
#  '77 ST',
#  '86 ST',
#  'BAY RIDGE-95 ST',
#  '8 AV',
#  'FT HAMILTON PKY',
#  'NEW UTRECHT AV',
#  '18 AV',
#  '20 AV',
#  'BAY PKWY',
#  '9 AV',
#  '50 ST',
#  '55 ST',
#  '71 ST',
#  '79 ST',
#  '25 AV',
#  'BAY 50 ST',
#  'CONEY IS-STILLW',
#  'W 8 ST-AQUARIUM',
#  '6 AV',
#  '3 AV',
#  '1 AV',
#  'BEDFORD AV',
#  'LORIMER ST',
#  'GRAHAM AV',
#  'GRAND ST',
#  'MONTROSE AV',
#  'MORGAN AV',
#  'JEFFERSON ST',
#  'MYRTLE-WYCKOFF',
#  'HALSEY ST',
#  'WILSON AV',
#  'BUSHWICK AV',
#  'ATLANTIC AV',
#  'SUTTER AV',
#  'LIVONIA AV',
#  'NEW LOTS',
#  'EAST 105 ST',
#  'CANARSIE-ROCKAW',
#  'MARCY AV',
#  'HEWES ST',
#  'FLUSHING AV',
#  'MYRTLE AV',
#  'KOSCIUSZKO ST',
#  'GATES AV',
#  'CHAUNCEY ST',
#  'ALABAMA AV',
#  'VAN SICLEN AV',
#  'CLEVELAND ST',
#  'NORWOOD AV',
#  'CRESCENT ST',
#  'CYPRESS HILLS',
#  '75 ST-ELDERTS',
#  '85 ST-FOREST PK',
#  'WOODHAVEN BLVD',
#  '104 ST',
#  '111 ST',
#  '121 ST',
#  'CENTRAL AV',
#  'KNICKERBOCKER',
#  'SENECA AVE',
#  'FOREST AVE',
#  'FRESH POND RD',
#  'METROPOLITAN AV',
#  'INWOOD-207 ST',
#  'DYCKMAN ST',
#  '190 ST',
#  '181 ST',
#  '175 ST',
#  '168 ST',
#  '163 ST-AMSTERDM',
#  '155 ST',
#  '145 ST',
#  '135 ST',
#  '125 ST',
#  '116 ST',
#  'CATHEDRAL PKWY',
#  '103 ST',
#  '96 ST',
#  '81 ST-MUSEUM',
#  '72 ST',
#  '59 ST COLUMBUS',
#  '42 ST-PORT AUTH',
#  '34 ST-PENN STA',
#  '14 ST',
#  'W 4 ST-WASH SQ',
#  'SPRING ST',
#  'WORLD TRADE CTR',
#  'HIGH ST',
#  'HOYT-SCHER',
#  'LAFAYETTE AV',
#  'CLINTON-WASH AV',
#  'FRANKLIN AV',
#  'NOSTRAND AV',
#  'KINGSTON-THROOP',
#  'UTICA AV',
#  'RALPH AV',
#  'ROCKAWAY AV',
#  'BROADWAY JCT',
#  'LIBERTY AV',
#  'VAN SICLEN AVE',
#  'SHEPHERD AV',
#  'EUCLID AV',
#  'GRANT AV',
#  '80 ST',
#  '88 ST',
#  'ROCKAWAY BLVD',
#  'OZONE PK LEFFRT',
#  'AQUEDUCT N.COND',
#  'AQUEDUCT RACETR',
#  'HOWARD BCH JFK',
#  'BROAD CHANNEL',
#  'BEACH 90 ST',
#  'BEACH 98 ST',
#  'BEACH 105 ST',
#  'ROCKAWAY PARK B',
#  'BEACH 67 ST',
#  'BEACH 60 ST',
#  'BEACH 44 ST',
#  'BEACH 36 ST',
#  'BEACH 25 ST',
#  'FAR ROCKAWAY',
#  '161/YANKEE STAD',
#  '167 ST',
#  '170 ST',
#  '174-175 STS',
#  'TREMONT AV',
#  '182-183 STS',
#  'FORDHAM RD',
#  'KINGSBRIDGE RD',
#  'BEDFORD PK BLVD',
#  'NORWOOD 205 ST',
#  '5 AV/53 ST',
#  'LEXINGTON AV/53',
#  'COURT SQ-23 ST',
#  'QUEENS PLAZA',
#  'STEINWAY ST',
#  '46 ST',
#  'NORTHERN BLVD',
#  '65 ST',
#  'JKSN HT-ROOSVLT',
#  'ELMHURST AV',
#  'GRAND-NEWTOWN',
#  '63 DR-REGO PARK',
#  '67 AV',
#  'FOREST HILLS 71',
#  '75 AV',
#  'KEW GARDENS',
#  'BRIARWOOD',
#  'SUTPHIN BLVD',
#  'PARSONS BLVD',
#  '169 ST',
#  'JAMAICA 179 ST',
#  'COURT SQ',
#  '21 ST',
#  'GREENPOINT AV',
#  'NASSAU ST',
#  'BROADWAY',
#  'MYRTLE-WILLOUGH',
#  'BEDFORD-NOSTRAN',
#  'CLASSON AV',
#  '47-50 STS ROCK',
#  '42 ST-BRYANT PK',
#  "B'WAY-LAFAYETTE",
#  '2 AV',
#  'EAST BROADWAY',
#  'YORK ST',
#  'BERGEN ST',
#  'CARROLL ST',
#  'SMITH-9 ST',
#  '4 AV-9 ST',
#  '15 ST-PROSPECT',
#  'DITMAS AV',
#  'AVENUE I',
#  'AVENUE N',
#  'AVENUE P',
#  'AVENUE X',
#  'NEPTUNE AV',
#  '57 ST',
#  'LEXINGTON AV/63',
#  'ROOSEVELT ISLND',
#  '21 ST-QNSBRIDGE',
#  'JAMAICA VAN WK',
#  'SUTPHIN-ARCHER',
#  'JAMAICA CENTER',
#  'ORCHARD BEACH',
#  'NEWARK HW BMEBE',
#  'HARRISON',
#  'JOURNAL SQUARE',
#  'GROVE STREET',
#  'EXCHANGE PLACE',
#  'PAVONIA/NEWPORT',
#  'CITY / BUS',
#  'PATH WTC',
#  'CHRISTOPHER ST',
#  '9TH STREET',
#  '14TH STREET',
#  'TWENTY THIRD ST',
#  'THIRTY ST',
#  'LACKAWANNA',
#  'THIRTY THIRD ST',
#  'NEWARK BM BW',
#  'NEWARK C',
#  'NEWARK HM HE',
#  'PATH WTC 2',
#  'PATH NEW WTC',
#  'SOUTH FERRY',
#  'WALL ST',
#  'FRANKLIN ST',
#  'HOUSTON ST',
#  '18 ST',
#  '66 ST-LINCOLN',
#  '116 ST-COLUMBIA',
#  '137 ST CITY COL',
#  '157 ST',
#  '191 ST',
#  '207 ST',
#  '215 ST',
#  'MARBLE HILL-225',
#  '231 ST',
#  '238 ST',
#  'V.CORTLANDT PK',
#  'BOWLING GREEN',
#  'BROOKLYN BRIDGE',
#  'BLEECKER ST',
#  'ASTOR PL',
#  '33 ST',
#  'GRD CNTRL-42 ST',
#  '51 ST',
#  '68ST-HUNTER CO',
#  '110 ST',
#  '138/GRAND CONC',
#  '149/GRAND CONC',
#  'MT EDEN AV',
#  '176 ST',
#  'BURNSIDE AV',
#  '183 ST',
#  'MOSHOLU PKWY',
#  'WOODLAWN',
#  'CENTRAL PK N110',
#  'HARLEM 148 ST',
#  '3 AV-149 ST',
#  'JACKSON AV',
#  'INTERVALE AV',
#  'SIMPSON ST',
#  'FREEMAN ST',
#  '174 ST',
#  'WEST FARMS SQ',
#  'E 180 ST',
#  'BRONX PARK EAST',
#  'PELHAM PKWY',
#  'ALLERTON AV',
#  'BURKE AV',
#  'GUN HILL RD',
#  '219 ST',
#  '225 ST',
#  '233 ST',
#  'NEREID AV',
#  'WAKEFIELD/241',
#  '3 AV 138 ST',
#  'BROOK AV',
#  'CYPRESS AV',
#  "E 143/ST MARY'S",
#  'E 149 ST',
#  'LONGWOOD AV',
#  'HUNTS POINT AV',
#  'WHITLOCK AV',
#  'ELDER AV',
#  'MORISN AV/SNDVW',
#  'ST LAWRENCE AV',
#  'PARKCHESTER',
#  'CASTLE HILL AV',
#  'ZEREGA AV',
#  'WESTCHESTER SQ',
#  'MIDDLETOWN RD',
#  'BUHRE AV',
#  'PELHAM BAY PARK',
#  '5 AVE',
#  'VERNON-JACKSON',
#  'HUNTERS PT AV',
#  'QUEENSBORO PLZ',
#  '39 AV',
#  '36 AV',
#  '30 AV',
#  'ASTORIA BLVD',
#  'ASTORIA DITMARS',
#  '33 ST-RAWSON ST',
#  '40 ST LOWERY ST',
#  '46 ST BLISS ST',
#  '52 ST',
#  '61 ST WOODSIDE',
#  '69 ST',
#  '74 ST-BROADWAY',
#  '82 ST-JACKSON H',
#  '90 ST-ELMHURST',
#  'JUNCTION BLVD',
#  '103 ST-CORONA',
#  'METS-WILLETS PT',
#  'FLUSHING-MAIN',
#  '34 ST-HUDSON YD',
#  'CLARK ST',
#  'HOYT ST',
#  'NEVINS ST',
#  'GRAND ARMY PLAZ',
#  'EASTN PKWY-MUSM',
#  'KINGSTON AV',
#  'CROWN HTS-UTICA',
#  'SUTTER AV-RUTLD',
#  'SARATOGA AV',
#  'JUNIUS ST',
#  'PENNSYLVANIA AV',
#  'NEW LOTS AV',
#  'PRESIDENT ST',
#  'STERLING ST',
#  'WINTHROP ST',
#  'BEVERLY RD',
#  'NEWKIRK AV',
#  'FLATBUSH AV-B.C',
#  'MORRIS PARK',
#  'BAYCHESTER AV',
#  'EASTCHSTER/DYRE',
#  'ST. GEORGE',
#  'TOMPKINSVILLE',
#  'RIT-MANHATTAN',
#  'RIT-ROOSEVELT']

# %%
stations_transit = data_daily.groupby(['STATION', 'DATE'])['TRANSITING'].sum()
# stations_transit = data_daily.groupby(['STATION', 'DATE'], as_index=False)['TRANSITING'].sum()

# %%
stations_transit.head()
# Out:
# STATION  DATE
# 1 AV     05/29/2016    30828.0
#          05/30/2016    28051.0
#          05/31/2016    23702.0
#          06/01/2016    42811.0
#          06/02/2016    43633.0
# Name: TRANSITING, dtype: float64

# %%
stations_transit = pd.DataFrame(stations_transit)

# %%
stations_transit['index'] = stations_transit.index
stations_transit.head()
# Out:
#                     TRANSITING               index
# STATION DATE
# 1 AV    05/29/2016     30828.0  (1 AV, 05/29/2016)
#         05/30/2016     28051.0  (1 AV, 05/30/2016)
#         05/31/2016     23702.0  (1 AV, 05/31/2016)
#         06/01/2016     42811.0  (1 AV, 06/01/2016)
#         06/02/2016     43633.0  (1 AV, 06/02/2016)

# %%
stations_transit[['STATION', 'DATE']] = stations_transit['index'].apply(pd.Series)

# %%
stations_transit.drop('index', 1, inplace=True)

# %%
stations_transit.head()
# Out:
#                     TRANSITING STATION        DATE
# STATION DATE
# 1 AV    05/29/2016     30828.0    1 AV  05/29/2016
#         05/30/2016     28051.0    1 AV  05/30/2016
#         05/31/2016     23702.0    1 AV  05/31/2016
#         06/01/2016     42811.0    1 AV  06/01/2016
#         06/02/2016     43633.0    1 AV  06/02/2016

# %% [markdown]
# Make a column containing the day of the week

# %%
stations_transit['DATE'] = pd.to_datetime(stations_transit['DATE'])
stations_transit['DAY_OF_WEEK'] = stations_transit['DATE'].dt.weekday_name

# %%
stations_transit.head()
# Out:
#                     TRANSITING STATION       DATE DAY_OF_WEEK
# STATION DATE
# 1 AV    05/29/2016     30828.0    1 AV 2016-05-29      Sunday
#         05/30/2016     28051.0    1 AV 2016-05-30      Monday
#         05/31/2016     23702.0    1 AV 2016-05-31     Tuesday
#         06/01/2016     42811.0    1 AV 2016-06-01   Wednesday
#         06/02/2016     43633.0    1 AV 2016-06-02    Thursday

# %%
stations_transit.reset_index(inplace=True, drop=True)

# %%
stations_transit.head()
# Out:
#    TRANSITING STATION       DATE DAY_OF_WEEK
# 0     30828.0    1 AV 2016-05-29      Sunday
# 1     28051.0    1 AV 2016-05-30      Monday
# 2     23702.0    1 AV 2016-05-31     Tuesday
# 3     42811.0    1 AV 2016-06-01   Wednesday
# 4     43633.0    1 AV 2016-06-02    Thursday

# %%
stations_transit.to_csv('/Users/aleksandra/ds/metis/Project-Benson/Data/per_station.csv')

# %% [markdown]
# Make df that sums transit per station per day of the week.

# %%
transit_dw_stations = stations_transit.groupby(['STATION', 'DAY_OF_WEEK'])['TRANSITING'].sum()

# %%
transit_dw_stations = pd.DataFrame(transit_dw_stations)

# %%
transit_dw_stations.head()
# Out:
#                      TRANSITING
# STATION DAY_OF_WEEK
# 1 AV    Friday         692467.0
#         Monday         433302.0
#         Saturday       675612.0
#         Sunday         527998.0
#         Thursday       691732.0

# %%
transit_dw_stations['index'] = transit_dw_stations.index
transit_dw_stations.head()
# Out:
#                      TRANSITING             index
# STATION DAY_OF_WEEK
# 1 AV    Friday         692467.0    (1 AV, Friday)
#         Monday         433302.0    (1 AV, Monday)
#         Saturday       675612.0  (1 AV, Saturday)
#         Sunday         527998.0    (1 AV, Sunday)
#         Thursday       691732.0  (1 AV, Thursday)

# %%
transit_dw_stations[['STATION', 'DAY_OF_WEEK']] = transit_dw_stations['index'].apply(pd.Series)

# %%
transit_dw_stations.head()
# Out:
#                      TRANSITING             index STATION DAY_OF_WEEK
# STATION DAY_OF_WEEK
# 1 AV    Friday         692467.0    (1 AV, Friday)    1 AV      Friday
#         Monday         433302.0    (1 AV, Monday)    1 AV      Monday
#         Saturday       675612.0  (1 AV, Saturday)    1 AV    Saturday
#         Sunday         527998.0    (1 AV, Sunday)    1 AV      Sunday
#         Thursday       691732.0  (1 AV, Thursday)    1 AV    Thursday

# %%
transit_dw_stations.drop('index', 1, inplace=True)

# %%
transit_dw_stations.reset_index(inplace=True, drop=True)

# %%
transit_dw_stations.head(7)
# Out:
#    TRANSITING STATION DAY_OF_WEEK
# 0    692467.0    1 AV      Friday
# 1    433302.0    1 AV      Monday
# 2    675612.0    1 AV    Saturday
# 3    527998.0    1 AV      Sunday
# 4    691732.0    1 AV    Thursday
# 5    600885.0    1 AV     Tuesday
# 6    675432.0    1 AV   Wednesday

# %%
transit_dw_stations.to_csv('/Users/aleksandra/ds/metis/Project-Benson/Data/station_dow.csv')

# %% [markdown]
# Now we have three csv's:
# * data_daily with everything
# * stations_transit with transit per station per day
# * transit_dw_stations with transit per station per weekday
#
# We are going to add a column with the weather on a certain day

# %%
len(data_daily)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-47712f664ece> in <module>()
# ----> 1 len(data_daily)
#
# NameError: name 'data_daily' is not defined

# %%
weather_data = pd.read_csv('/Users/aleksandra/ds/metis/Project-Benson/Data/NYC_rainy_days.csv')

# %%
weather_data.head()
# Out:
#    Unnamed: 0            STATION                STATION_NAME        DATE  PRCP
# 0        4645  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  2016-06-27  0.45
# 1        4646  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  2016-06-28  0.12
# 2        4647  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  2016-06-29  0.01
# 3        4648  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  2016-06-30  0.00
# 4        4649  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  2016-07-01  0.83

# %%
data_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/29/2016  5683957  05/28/2016
# 2  A002  R051  02-00-00   59 ST  05/30/2016  5684749  05/29/2016
# 3  A002  R051  02-00-00   59 ST  05/31/2016  5685506  05/30/2016
# 4  A002  R051  02-00-00   59 ST  06/01/2016  5687282  05/31/2016
# 5  A002  R051  02-00-00   59 ST  06/02/2016  5689073  06/01/2016
#
#    PREV_ENTRIES    EXITS  PREV_EXITS  SALDO_ENTRIES  SALDO_EXITS  TRANSITING
# 1     5682962.0  1924599   1924340.0          995.0        259.0      1254.0
# 2     5683957.0  1924791   1924599.0          792.0        192.0       984.0
# 3     5684749.0  1925050   1924791.0          757.0        259.0      1016.0
# 4     5685506.0  1925601   1925050.0         1776.0        551.0      2327.0
# 5     5687282.0  1926208   1925601.0         1791.0        607.0      2398.0

# %% [markdown]
# We want to add the column PRCP to the data_daily dataframe, mathcing on date. First we need to cnvert the DATE columns in both dataframes to the same format.

# %%
data_daily['DATE_2'] = pd.to_datetime(data_daily['DATE'], format = '%m/%d/%Y')
# Out:
# //anaconda/envs/py3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
small_weather = weather_data[['DATE', 'PRCP']]
small_weather.head()
# Out:
#          DATE  PRCP
# 0  2016-06-27  0.45
# 1  2016-06-28  0.12
# 2  2016-06-29  0.01
# 3  2016-06-30  0.00
# 4  2016-07-01  0.83

# %%
data_daily_weather = pd.merge(data_daily, small_weather, left_on = 'DATE_2', right_on='DATE', how = 'left')

# %%
data_daily_weather['PRCP'].isnull().sum()
# Out:
# 509155

# %%
len(data_daily_weather['PRCP'])
# Out:
# 509155

# %% [markdown]
# 25% difference is due to the fact that the mta data we used is for June-September, while the weather data is from July-September. We just dropped June.

# %%
data_daily_weather = data_daily.dropna(axis = 0)

# %%
data_daily_weather.to_csv('/Users/aleksandra/ds/metis/Project-Benson/Data/data_daily_weather.csv')
