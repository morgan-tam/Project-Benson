# %% [markdown]
# API key = AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from itertools import product

# %% [markdown]
# # Finding Lat and Long of Top Stations

# %%
station_df = pd.read_csv('Data/StationEntrances.csv')
station_df.head(3)
# Out:
#   Division     Line  Station_Name  Station_Latitude  Station_Longitude  \
# 0      BMT  Astoria  Ditmars Blvd         40.775036         -73.912034
# 1      BMT  Astoria  Ditmars Blvd         40.775036         -73.912034
# 2      BMT  Astoria  Ditmars Blvd         40.775036         -73.912034
#
#   Route_1 Route_2 Route_3 Route_4 Route_5    ...     Staffing Staff_Hours  \
# 0       N       Q     NaN     NaN     NaN    ...         FULL         NaN
# 1       N       Q     NaN     NaN     NaN    ...         FULL         NaN
# 2       N       Q     NaN     NaN     NaN    ...         FULL         NaN
#
#      ADA  ADA_Notes  Free_Crossover  North_South_Street East_West_Street  \
# 0  False        NaN            True             31st St         23rd Ave
# 1  False        NaN            True             31st St         23rd Ave
# 2  False        NaN            True             31st St         23rd Ave
#
#   Corner   Latitude  Longitude
# 0     NW  40.775149 -73.912074
# 1     NE  40.774810 -73.912151
# 2     NE  40.775025 -73.911891
#
# [3 rows x 30 columns]

# %%
top20_to_lat_long = {
 'GRDCNTRL42ST4567S': ('Grand Central-42nd St', 40.751776, -73.976848),
 '34STHERALDSQBDFMNQR' : ('34 St - Herald Sq', 40.749567, -73.98795),
 'TIMESSQ42ST1237ACENQRS': ('Times Square-42nd St', 40.754672, -73.986754),
 '14STUNIONSQ456LNQR': ('14 St - Union Sq', 40.735736, -73.990568),
 'FULTONST2345ACJZ': ('Fulton St', 40.710374, -74.007582),
 '34STPENNSTAACE': ('34 St - Penn Station', 40.752287, -73.993391),
 '42STPORTAUTH1237ACENQRS': ('42 St - Port Authority Bus Terminal', 40.757308, -73.989735),
 '59STCOLUMBUS1ABCD': ('59 St - Columbus Circle', 40.768296, -73.981736),
 '59ST456NQR': ('59 St', 40.762526,-73.967967),
 '86ST456': ('86 St', 40.779492, -73.955589),
 '4750STSROCKBDFM': ('47-50 Sts - Rockefeller Ctr', 40.758663, -73.981329),
 'FLUSHINGMAIN7': ('Flushing - Main St', 40.7596, -73.83003),
 '34STPENNSTA123ACE': ('34 St - Penn Station', 40.750373, -73.991057),
 'JKSNHTROOSVLT7EFMR': ('Jackson Hts - Roosevelt Av', 40.746644, -73.891338),
 '42STBRYANTPK7BDFM': ('42 St - Bryant Pk', 40.754222, -73.984569),
 'ATLAVBARCLAY2345BDNQR': ('Atlantic Av - Barclays Ctr', 40.683666, -73.97881),
 'CANALST6JNQRZ': ('Canal St', 40.718092, -73.999892 ),
 'LEXINGTONAV536EM': ('Lexington Av/53 St', 40.757552, -73.969055),
 '96ST123': ('96 St', 40.793919, -73.972323),
 '14ST123FLM': ('14 St', 40.737826, -74.000201),
}

# %%
top20_df = pd.DataFrame(top20_to_lat_long).T
station_latitude = list(top20_df.loc[:,1])
station_longitude = list(top20_df.loc[:,2])

# %% [markdown]
# # Finding Lat and Long of Top Earners

# %%
income_df = pd.read_csv('Data/medianhouseholdincomecensustract.csv')
income_df.head(3)
# Out:
#    FID  STATEFP10  COUNTYFP10  TRACTCE10      GEOID10  INTPTLAT10  INTPTLON10  \
# 0    0         34          17      32400  34017032400   40.792844  -74.013482
# 1    1         34          17      10100  34017010100   40.691559  -74.110913
# 2    2         34          17      10200  34017010200   40.682103  -74.104573
#
#         State         COUNTY  HH_COUNT     ...      MSMOC_TOT_      TAX_RET  \
# 0  New Jersey  Hudson County      2187     ...           22740  2264.889916
# 1  New Jersey  Hudson County      2255     ...           27804  2363.430717
# 2  New Jersey  Hudson County      1218     ...           28068  1260.718928
#
#     Avg_TransC   REtaxperow     DISP_INC   energy_cos  REtax_ACS      AVG_TTL  \
# 0  4145.566539  4966.370331  12232.00950  1773.280152       7735  5007.444405
# 1  5969.286255  4490.984109  22077.84024  1876.844806       7917  6146.888195
# 2  6014.489564  3339.224580  20488.60531  2167.175106       7692  6193.436421
#
#             LOCALNAME  Shape_Area
# 0  West New York Town    0.000036
# 1        Bayonne City    0.000106
# 2        Bayonne City    0.000031
#
# [3 rows x 28 columns]

# %%
#Median Household Income more than 100k
rich_families = income_df[(income_df['MHI']>100000) & \
                         ((income_df['COUNTY'] == 'New York County') \
                          | (income_df['COUNTY'] == 'Kings County') \
                          | (income_df['COUNTY'] == 'Bronx County') \
                          | (income_df['COUNTY'] == 'Queens County'))]
rich_families.LOCALNAME.value_counts().head(10)
# Out:
# Upper East Side (59-79)      11
# Upper East Side (79-96)      10
# Upper West Side (59-79)       9
# Park Slope                    6
# Upper West Side (79-96)       5
# Midtown East                  5
# Greenwich Village-Central     5
# Midtown West                  5
# Forest Hills                  4
# Flatiron                      4
# Name: LOCALNAME, dtype: int64

# %%
rich_latitude = rich_families.INTPTLAT10
rich_longitude = rich_families.INTPTLON10

# %% [markdown]
# # Finding Lat and Long of Top Givers

# %%
irs_df = pd.read_excel('Data/IRS_SOI_NY_2014.csv')
irs_df = irs_df.ix[10:]
irs_df.head(7)
# Out:
#    ZIP\ncode [1] Size of adjusted gross income  Number of returns  \
# 10         10001                           NaN            14080.0
# 11         10001              $1 under $25,000             3880.0
# 12         10001         $25,000 under $50,000             2530.0
# 13         10001         $50,000 under $75,000             1850.0
# 14         10001        $75,000 under $100,000             1300.0
# 15         10001       $100,000 under $200,000             2350.0
# 16         10001              $200,000 or more             2170.0
#
#     Number of single returns  Number of joint returns  \
# 10                   10200.0                   2410.0
# 11                    3010.0                    350.0
# 12                    1890.0                    250.0
# 13                    1470.0                    190.0
# 14                    1000.0                    170.0
# 15                    1680.0                    530.0
# 16                    1150.0                    920.0
#
#     Number of head of household returns  \
# 10                               1090.0
# 11                                430.0
# 12                                320.0
# 13                                140.0
# 14                                 80.0
# 15                                 70.0
# 16                                 50.0
#
#     Number with paid preparer's signature  Number of exemptions  \
# 10                                 8690.0               19370.0
# 11                                 2270.0                4840.0
# 12                                 1430.0                3420.0
# 13                                 1080.0                2360.0
# 14                                  790.0                1670.0
# 15                                 1460.0                3290.0
# 16                                 1660.0                3790.0
#
#     Number of dependents Number of volunteer prepared returns [2]  \
# 10                3250.0                                      430
# 11                 930.0                                      290
# 12                 680.0                                      120
# 13                 330.0                                       20
# 14                 200.0                                        0
# 15                 410.0                                        0
# 16                 700.0                                        0
#
#        ...      Total tax liability [9] Unnamed: 116  Additional Medicare tax  \
# 10     ...                        12090       564573                     1790
# 11     ...                         2130         2367                        0
# 12     ...                         2340         7919                        0
# 13     ...                         1830        14162                        0
# 14     ...                         1290        16562                        0
# 15     ...                         2330        57112                      100
# 16     ...                         2170       466451                     1690
#
#    Unnamed: 118 Net investment income tax Unnamed: 120  \
# 10         6152                      1610        10890
# 11            0                         0            0
# 12            0                         0            0
# 13            0                         0            0
# 14            0                         0            0
# 15           31                        30           12
# 16         6121                      1580        10878
#
#    Tax due at time of filing [10] Unnamed: 122 Overpayments refunded [11]  \
# 10                           3720        46427                       9190
# 11                            720          884                       2670
# 12                            530         1345                       1910
# 13                            450         1301                       1330
# 14                            300         1289                        940
# 15                            580         3830                       1630
# 16                           1140        37778                        710
#
#    Unnamed: 124
# 10        46196
# 11         4790
# 12         4371
# 13         3274
# 14         2851
# 15         7178
# 16        23732
#
# [7 rows x 125 columns]

# %%
#Cutting off deduction by only those in the $100k or more bracket
irs_df = irs_df[(irs_df['Size of adjusted gross income']=='$100,000 under $200,000')\
             | (irs_df['Size of adjusted gross income']=='$200,000 or more')]

# %%
irs_df.rename(columns={'Total itemized deductions': 'Total Itemized Deductions Amount'},inplace=True)
irs_df.rename(columns={'Unnamed: 57': 'Amount of AGI'},inplace=True)

# %%
itemized_deduction = irs_df.groupby('ZIP\ncode [1]')['Total Itemized Deductions Amount'].sum()
Amount_of_AGI = irs_df.groupby('ZIP\ncode [1]')['Amount of AGI'].sum()

# %%
deduction_df = pd.concat([itemized_deduction, Amount_of_AGI], axis=1)

# %%
ratio = np.true_divide(itemized_deduction,Amount_of_AGI)
# Out:
# /Users/CptMorgan/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':

# %%
generous_ratio = ratio[ratio[:] > 0.01]

# %%
generous_zip_codes = list(generous_ratio.index)

# %%
zip_to_lat_long = pd.read_csv('Data/Zip_to_Lat_Lon.txt')

# %%
generous_lat = []
generous_long = []
for zip_code in generous_zip_codes:
    generous_lat.append(float(zip_to_lat_long[zip_to_lat_long.ZIP == zip_code].LAT))
    generous_long.append(float(zip_to_lat_long[zip_to_lat_long.ZIP == zip_code].LNG))

# %% [markdown]
# # Geo-Plotting

# %%
from bokeh.io import output_notebook, show
from bokeh.models import ( GMapPlot, GMapOptions, ColumnDataSource, \
                          Circle, DataRange1d, PanTool, \
                          WheelZoomTool, BoxSelectTool
)

# %%
def geoplotting(latitude,longitude,title):
    output_notebook()

    map_options = GMapOptions(lat=40.764811, lng=-73.973347, \
                              map_type="roadmap", zoom=11)

    plot = GMapPlot(
        x_range=DataRange1d(), y_range=DataRange1d(), \
        map_options=map_options
    )
    
    plot.title.text = title

    plot.api_key = "AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg"

    source = ColumnDataSource(
        data=dict(
            lat=latitude, #needs to be a list of latitude
            lon=longitude, #needs to be a corresponding list of long
        )
    )

    circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
    plot.add_glyph(source, circle)

    plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
    show(plot)

# %%
geoplotting(station_latitude,station_longitude,"Top Stations")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="46037ecd-ee84-4b6a-9770-571636fedb29">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cd4ffc78-a39d-44cd-853b-c899ec53507f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cd4ffc78-a39d-44cd-853b-c899ec53507f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd4ffc78-a39d-44cd-853b-c899ec53507f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd4ffc78-a39d-44cd-853b-c899ec53507f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0398837f-e3f5-4a26-b62e-a6bdedd79dbc":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d71eb590-f4fd-4508-a98f-9da83f34b77a","type":"PanTool"},{"id":"10eaca5d-9bd0-415a-b5bf-53e364863685","type":"WheelZoomTool"},{"id":"a6009f74-b830-48da-b758-0fb51a3c9b3e","type":"BoxSelectTool"}]},"id":"47bcb64b-3f51-4a13-a3f1-afbe3e567439","type":"Toolbar"},{"attributes":{},"id":"cddfef02-363f-4e00-97ad-e64a2bbc43d9","type":"LinearScale"},{"attributes":{"data_source":{"id":"c554a593-0caa-40bf-be10-57c809ce6330","type":"ColumnDataSource"},"glyph":{"id":"edf84122-5156-4c93-916d-29afe2cf5be0","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"8b1da961-7cc6-4c43-9a22-5915d98f57e4","type":"GlyphRenderer"},{"attributes":{"api_key":"AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg","map_options":{"id":"8403eb47-13d9-4d75-8b61-261422f4d533","type":"GMapOptions"},"renderers":[{"id":"8b1da961-7cc6-4c43-9a22-5915d98f57e4","type":"GlyphRenderer"},{"id":"b0d3afd4-a1be-43d0-9189-2457ef1dbb7a","type":"BoxAnnotation"}],"title":{"id":"4396bc2b-037e-47be-b84c-577556bc928f","type":"Title"},"tool_events":{"id":"9110dc51-5dbb-4a90-8794-17aff4f511cf","type":"ToolEvents"},"toolbar":{"id":"47bcb64b-3f51-4a13-a3f1-afbe3e567439","type":"Toolbar"},"x_range":{"id":"2b617ee1-4239-447e-956b-ba100858291a","type":"DataRange1d"},"x_scale":{"id":"5de05b5d-9c5e-470c-840a-938ad31cd81a","type":"LinearScale"},"y_range":{"id":"0daba61d-a8d9-4efb-bf68-d1ab00ebf9ea","type":"DataRange1d"},"y_scale":{"id":"cddfef02-363f-4e00-97ad-e64a2bbc43d9","type":"LinearScale"}},"id":"712d0342-c3c8-49a3-91f8-feecf28c1bfd","type":"GMapPlot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b0d3afd4-a1be-43d0-9189-2457ef1dbb7a","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"2b617ee1-4239-447e-956b-ba100858291a","type":"DataRange1d"},{"attributes":{"plot":{"id":"712d0342-c3c8-49a3-91f8-feecf28c1bfd","type":"GMapPlot"}},"id":"10eaca5d-9bd0-415a-b5bf-53e364863685","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"Top Stations"},"id":"4396bc2b-037e-47be-b84c-577556bc928f","type":"Title"},{"attributes":{},"id":"5de05b5d-9c5e-470c-840a-938ad31cd81a","type":"LinearScale"},{"attributes":{"callback":null},"id":"0daba61d-a8d9-4efb-bf68-d1ab00ebf9ea","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":[40.737826,40.735736,40.749567,40.750373,40.752287,40.754222,40.757308,40.758663,40.762526,40.768296,40.779492,40.793919,40.683666,40.718092,40.7596,40.710374,40.751776,40.746644,40.757552,40.754672],"lon":[-74.000201,-73.990568,-73.98795,-73.991057,-73.993391,-73.984569,-73.989735,-73.981329,-73.967967,-73.981736,-73.955589,-73.972323,-73.97881,-73.999892,-73.83003,-74.007582,-73.976848,-73.891338,-73.969055,-73.986754]}},"id":"c554a593-0caa-40bf-be10-57c809ce6330","type":"ColumnDataSource"},{"attributes":{"lat":40.764811,"lng":-73.973347,"zoom":11},"id":"8403eb47-13d9-4d75-8b61-261422f4d533","type":"GMapOptions"},{"attributes":{"callback":null,"overlay":{"id":"b0d3afd4-a1be-43d0-9189-2457ef1dbb7a","type":"BoxAnnotation"},"plot":{"id":"712d0342-c3c8-49a3-91f8-feecf28c1bfd","type":"GMapPlot"}},"id":"a6009f74-b830-48da-b758-0fb51a3c9b3e","type":"BoxSelectTool"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"edf84122-5156-4c93-916d-29afe2cf5be0","type":"Circle"},{"attributes":{},"id":"9110dc51-5dbb-4a90-8794-17aff4f511cf","type":"ToolEvents"},{"attributes":{"plot":{"id":"712d0342-c3c8-49a3-91f8-feecf28c1bfd","type":"GM ...
#             var render_items = [{"docid":"0398837f-e3f5-4a26-b62e-a6bdedd79dbc","elementid":"cd4ffc78-a39d-44cd-853b-c899ec53507f","modelid":"712d0342-c3c8-49a3-91f8-feecf28c1bfd"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document

# %%
geoplotting(rich_latitude,rich_longitude,"Affluent Areas")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7f269e8b-636e-415a-9db4-74095783f8b4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="164ccad2-fcf1-45c4-9f51-b81d32921bef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("164ccad2-fcf1-45c4-9f51-b81d32921bef");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("164ccad2-fcf1-45c4-9f51-b81d32921bef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '164ccad2-fcf1-45c4-9f51-b81d32921bef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cd04b356-f623-4ba8-8d19-1eb540b4a2e7":{"roots":{"references":[{"attributes":{"plot":{"id":"dcab0557-420d-44c9-9f51-07b0c1c97fe1","type":"GMapPlot"}},"id":"4cc69963-86ce-4fa5-9e52-cd3094d4cd17","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"7744b392-4c14-4c65-9928-eed40d35e02e","type":"Circle"},{"attributes":{},"id":"3a1d51e4-0973-4149-bd62-5cf932260270","type":"LinearScale"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"169134f4-4a25-4346-84e3-8f7484c95659","type":"BoxAnnotation"},{"attributes":{"lat":40.764811,"lng":-73.973347,"zoom":11},"id":"16ef8ad7-b03b-4a78-b5bb-3d13e08e8c00","type":"GMapOptions"},{"attributes":{"plot":{"id":"dcab0557-420d-44c9-9f51-07b0c1c97fe1","type":"GMapPlot"}},"id":"648a2a39-69e7-46d9-8e36-dc167c705560","type":"WheelZoomTool"},{"attributes":{},"id":"0492c1fd-f9e1-44fa-a7ad-11116e51a7d6","type":"LinearScale"},{"attributes":{"plot":null,"text":"Affluent Areas"},"id":"213012f9-e8f4-4b99-bb08-b39984d17e14","type":"Title"},{"attributes":{"api_key":"AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg","map_options":{"id":"16ef8ad7-b03b-4a78-b5bb-3d13e08e8c00","type":"GMapOptions"},"renderers":[{"id":"67465008-7d64-420f-a1c2-a8b248639302","type":"GlyphRenderer"},{"id":"169134f4-4a25-4346-84e3-8f7484c95659","type":"BoxAnnotation"}],"title":{"id":"213012f9-e8f4-4b99-bb08-b39984d17e14","type":"Title"},"tool_events":{"id":"ce31dd84-c157-4558-9c1d-c1d306d06e74","type":"ToolEvents"},"toolbar":{"id":"be194328-8ef6-4105-adba-99eff6ed58f0","type":"Toolbar"},"x_range":{"id":"e7fcf6ba-a35c-4f0e-8047-35d26a545839","type":"DataRange1d"},"x_scale":{"id":"3a1d51e4-0973-4149-bd62-5cf932260270","type":"LinearScale"},"y_range":{"id":"7dad2a93-a5de-4120-9ab4-ebc9eb4f37c6","type":"DataRange1d"},"y_scale":{"id":"0492c1fd-f9e1-44fa-a7ad-11116e51a7d6","type":"LinearScale"}},"id":"dcab0557-420d-44c9-9f51-07b0c1c97fe1","type":"GMapPlot"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4cc69963-86ce-4fa5-9e52-cd3094d4cd17","type":"PanTool"},{"id":"648a2a39-69e7-46d9-8e36-dc167c705560","type":"WheelZoomTool"},{"id":"9ef8596d-f431-4cb8-b89b-93d2dfbb0836","type":"BoxSelectTool"}]},"id":"be194328-8ef6-4105-adba-99eff6ed58f0","type":"Toolbar"},{"attributes":{},"id":"ce31dd84-c157-4558-9c1d-c1d306d06e74","type":"ToolEvents"},{"attributes":{"callback":null},"id":"7dad2a93-a5de-4120-9ab4-ebc9eb4f37c6","type":"DataRange1d"},{"attributes":{"data_source":{"id":"e74d6739-e0b6-425d-8051-8dea94a0de9d","type":"ColumnDataSource"},"glyph":{"id":"7744b392-4c14-4c65-9928-eed40d35e02e","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"67465008-7d64-420f-a1c2-a8b248639302","type":"GlyphRenderer"},{"attributes":{"callback":null,"overlay":{"id":"169134f4-4a25-4346-84e3-8f7484c95659","type":"BoxAnnotation"},"plot":{"id":"dcab0557-420d-44c9-9f51-07b0c1c97fe1","type":"GMapPlot"}},"id":"9ef8596d-f431-4cb8-b89b-93d2dfbb0836","type":"BoxSelectTool"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":{"__ndarray__":"...","dtype":"float64","shape":[118]},"lon":{"__ndarray__":"...","dtype":"float64","shape":[118]}}},"id":"e74d6739-e0b6-425d-8051-8dea94a0de9d","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"e7fcf6ba-a35c-4f0e-8047-35d26a545839","type":"DataRange1d"}],"root_ids":["dcab0557-420d-44c9-9f51-07b0c1c97fe1"]},"title":"Bokeh Application","version":"0.12.6"}};
#             var render_items = [{"docid":"cd04b356-f623-4ba8-8d19-1eb540b4a2e7","elementid":"164ccad2-fcf1-45c4-9f51-b81d32921bef","modelid":"dcab0557-420d-44c9-9f51-07b0c1c97fe1"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }i

# %%
geoplotting(generous_lat,generous_long, "The Generous (OR Tax hacking)")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="020f2e2a-ff0f-4b70-9a89-f5128f88ed05">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="560086b5-a6e4-4d21-abbe-3622ee813ccc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("560086b5-a6e4-4d21-abbe-3622ee813ccc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("560086b5-a6e4-4d21-abbe-3622ee813ccc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '560086b5-a6e4-4d21-abbe-3622ee813ccc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e5b08bef-59f1-4267-9e77-233f909e1127":{"roots":{"references":[{"attributes":{"callback":null},"id":"d2a4c40a-e11b-4c20-bf6e-99568f769729","type":"DataRange1d"},{"attributes":{"plot":{"id":"3061d623-9e72-4b63-beb0-c1b204419587","type":"GMapPlot"}},"id":"79c4af9f-4468-4d0b-9535-2c42aa304d93","type":"WheelZoomTool"},{"attributes":{},"id":"008ff80a-fb8b-4e5a-a82e-4061405fcb8b","type":"LinearScale"},{"attributes":{"callback":null},"id":"c0530ff8-7830-4991-8e8b-58a6997ee37b","type":"DataRange1d"},{"attributes":{},"id":"708761a0-de81-4fa5-99c7-566ba2220f18","type":"LinearScale"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4c765d20-1b2a-4538-a2c3-69c1eb16cabc","type":"BoxAnnotation"},{"attributes":{"api_key":"AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg","map_options":{"id":"b456542c-fcd2-4eb6-af24-981d56a9e267","type":"GMapOptions"},"renderers":[{"id":"092eacfa-755c-44a8-91ea-5267c62139e1","type":"GlyphRenderer"},{"id":"4c765d20-1b2a-4538-a2c3-69c1eb16cabc","type":"BoxAnnotation"}],"title":{"id":"db8f4087-fe13-4448-a352-c81386220e1b","type":"Title"},"tool_events":{"id":"3cf62af2-5bfa-40be-8908-c4d927e4aa93","type":"ToolEvents"},"toolbar":{"id":"8c8ddaee-9e9f-4ea7-b9ba-27de3be8cecc","type":"Toolbar"},"x_range":{"id":"c0530ff8-7830-4991-8e8b-58a6997ee37b","type":"DataRange1d"},"x_scale":{"id":"008ff80a-fb8b-4e5a-a82e-4061405fcb8b","type":"LinearScale"},"y_range":{"id":"d2a4c40a-e11b-4c20-bf6e-99568f769729","type":"DataRange1d"},"y_scale":{"id":"708761a0-de81-4fa5-99c7-566ba2220f18","type":"LinearScale"}},"id":"3061d623-9e72-4b63-beb0-c1b204419587","type":"GMapPlot"},{"attributes":{"lat":40.764811,"lng":-73.973347,"zoom":11},"id":"b456542c-fcd2-4eb6-af24-981d56a9e267","type":"GMapOptions"},{"attributes":{"data_source":{"id":"cccb5681-c1cf-497c-8291-1297a8445d47","type":"ColumnDataSource"},"glyph":{"id":"9f81a822-d282-40d5-9d32-27fa7cd1f3cc","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"092eacfa-755c-44a8-91ea-5267c62139e1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":[40.750633,40.715775,40.731829,40.688629999999996,40.709614,40.726399,40.739065000000004,40.742039,40.725581,40.734012,40.745224,40.798601,40.802381,40.811407,40.791763,40.818267,40.825288,40.838815000000004,40.850545000000004,40.867076000000004,40.795455,40.812957,40.709278000000005,40.830867,40.858305,40.761915,40.7693,40.708538,40.716921,40.627456,40.630688,40.629884999999994,40.609227000000004,40.596691,40.571768,40.509183,40.551884,40.531346,40.632647999999996,40.545237,40.599263,40.820479,40.837393,40.852779,40.805489,40.81471,40.829881,40.84715,40.862543,40.825866999999995,40.841758,40.847381,40.84328,40.880678,40.867787,40.822615,40.890964000000004,40.869953,40.868093,40.868607,40.88953,40.898868,40.829556,40.818690000000004,40.810549,40.875169,41.295608,41.011602,41.34209,41.410855,41.139472,41.265428,41.457619,41.461974,41.266143,41.226478,41.01031,41.059340999999996,41.375325,41.288102,41.321183000000005,41.023711999999996,41.099278000000005,41.036927,41.335169,41.269098,41.33974,41.381113,40.952693,41.195609000000005,41.313334000000005,41.245696,41.200584,40.905448,40.924459999999996,40.908584000000005,41.340527,41.19448,41.289483000000004,41.2896,41.130067,41.015857000000004,41.221577,41.320276,41.395364,41.336622999999996,41.334143,41.255269,41.090097,41.113425,41.085896999999996,41.288222999999995,41.032932,41.0544,41.071512,41.010525,41.020571999999994,41.039089000000004,40.94542,40.959829,40.919729,40.919705,40.989821,40.960533,40.938266999999996,40.954634999999996,40.967157,40.91757,40.900458,40.946841,40.897721000000004,41.140772,41.068258,41.442343,41.319571999999994,41.344192,41.525959 ...

# %% [markdown]
# # Heatmaps

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg")

# %%
top20_locations = zip(station_latitude,station_longitude)
rich_locations = zip(rich_latitude,rich_longitude)
generous_locations = zip(generous_lat,generous_long)

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(top20_locations))
fig

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(rich_locations,point_radius = 10))
fig

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(generous_locations,point_radius = 20))
fig

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.marker_layer(top20_locations))
fig

# %%
top20_locations
# Out:
# [(40.737826, -74.000201),
#  (40.735736, -73.990568),
#  (40.749567, -73.98795),
#  (40.750373, -73.991057),
#  (40.752287, -73.993391),
#  (40.754222, -73.984569),
#  (40.757308, -73.989735),
#  (40.758663, -73.981329),
#  (40.762526, -73.967967),
#  (40.768296, -73.981736),
#  (40.779492, -73.955589),
#  (40.793919, -73.972323),
#  (40.683666, -73.97881),
#  (40.718092, -73.999892),
#  (40.7596, -73.83003),
#  (40.710374, -74.007582),
#  (40.751776, -73.976848),
#  (40.746644, -73.891338),
#  (40.757552, -73.969055),
#  (40.754672, -73.986754)]

# %%
station_latitude,station_longitude
# Out:
# ([40.737826,
#   40.735736,
#   40.749567,
#   40.750373,
#   40.752287,
#   40.754222,
#   40.757308,
#   40.758663,
#   40.762526,
#   40.768296,
#   40.779492,
#   40.793919,
#   40.683666,
#   40.718092,
#   40.7596,
#   40.710374,
#   40.751776,
#   40.746644,
#   40.757552,
#   40.754672],
#  [-74.000201,
#   -73.990568,
#   -73.98795,
#   -73.991057,
#   -73.993391,
#   -73.984569,
#   -73.989735,
#   -73.981329,
#   -73.967967,
#   -73.981736,
#   -73.955589,
#   -73.972323,
#   -73.97881,
#   -73.999892,
#   -73.83003,
#   -74.007582,
#   -73.976848,
#   -73.891338,
#   -73.969055,
#   -73.986754])
