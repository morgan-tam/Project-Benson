# %% [markdown]
# API key = AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# ## Finding Lat and Long of Top Stations

# %%
station_df = pd.read_csv('Data/StationEntrances.csv')

# %%
station_df.head(3)
# Out:
#   Division     Line  Station_Name  Station_Latitude  Station_Longitude  \
# 0      BMT  Astoria  Ditmars Blvd         40.775036         -73.912034
# 1      BMT  Astoria  Ditmars Blvd         40.775036         -73.912034
# 2      BMT  Astoria  Ditmars Blvd         40.775036         -73.912034
#
#   Route_1 Route_2 Route_3 Route_4 Route_5    ...     Staffing Staff_Hours  \
# 0       N       Q     NaN     NaN     NaN    ...         FULL         NaN
# 1       N       Q     NaN     NaN     NaN    ...         FULL         NaN
# 2       N       Q     NaN     NaN     NaN    ...         FULL         NaN
#
#      ADA  ADA_Notes  Free_Crossover  North_South_Street East_West_Street  \
# 0  False        NaN            True             31st St         23rd Ave
# 1  False        NaN            True             31st St         23rd Ave
# 2  False        NaN            True             31st St         23rd Ave
#
#   Corner   Latitude  Longitude
# 0     NW  40.775149 -73.912074
# 1     NE  40.774810 -73.912151
# 2     NE  40.775025 -73.911891
#
# [3 rows x 30 columns]

# %%
#Figuring out regular expressions in station names
station_name = ['Grand Central', 'Atlantic', '59th'] #Grand central, Atlantic Avenue, Columbus Circle
latitude = []
longitude = []
for name in station_name:
    latitude.append(station_df[station_df.Station_Name.str.contains('^'+name)].Station_Latitude.mean())
    longitude.append(station_df[station_df.Station_Name.str.contains('^'+name)].Station_Longitude.mean())

# %% [markdown]
# ## Finding Lat and Long of Top Demographics

# %%
#Matching CensusTrack to Lat/Long?

# %% [markdown]
# ## Geo-Plotting

# %%
from bokeh.io import output_notebook, show
from bokeh.models import ( GMapPlot, GMapOptions, ColumnDataSource, \
                          Circle, DataRange1d, PanTool, \
                          WheelZoomTool, BoxSelectTool
)

# %%
def geoplotting(latitude,longitude):
    output_notebook()

    map_options = GMapOptions(lat=40.764811, lng=-73.973347, \
                              map_type="roadmap", zoom=11)

    plot = GMapPlot(
        x_range=DataRange1d(), y_range=DataRange1d(), \
        map_options=map_options
    )
    
    plot.title.text = "New York City"

    plot.api_key = "AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg"

    source = ColumnDataSource(
        data=dict(
            lat=latitude, #needs to be a list of latitude
            lon=longitude, #needs to be a corresponding list of long
        )
    )

    circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
    plot.add_glyph(source, circle)

    plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
    show(plot)

# %%
geoplotting(latitude,longitude)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="34968357-707d-4da1-b837-7d052b974626">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f533f134-19fa-4bcb-92e0-5c5eb95d46c4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f533f134-19fa-4bcb-92e0-5c5eb95d46c4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f533f134-19fa-4bcb-92e0-5c5eb95d46c4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f533f134-19fa-4bcb-92e0-5c5eb95d46c4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d1745fea-f799-49c8-99e9-058d7883f39c":{"roots":{"references":[{"attributes":{"lat":40.764811,"lng":-73.973347,"zoom":11},"id":"3351ba3e-a735-4017-b33f-223d46b16e45","type":"GMapOptions"},{"attributes":{"plot":{"id":"c0ca1514-70ce-4fac-91df-7c1c485d6f3f","type":"GMapPlot"}},"id":"178a3965-455f-4174-a55c-f6b7920010e0","type":"PanTool"},{"attributes":{"plot":null,"text":"New York City"},"id":"31b4d95b-e1b3-43de-a73b-32bf45fb6558","type":"Title"},{"attributes":{"callback":null,"overlay":{"id":"f04fed8b-c038-4db7-906a-9ec14451d296","type":"BoxAnnotation"},"plot":{"id":"c0ca1514-70ce-4fac-91df-7c1c485d6f3f","type":"GMapPlot"}},"id":"d0e34465-021e-4a52-af2c-e6c2f9a262d2","type":"BoxSelectTool"},{"attributes":{"api_key":"AIzaSyBaExoC_xY6qKJ4TF3MkW78Hhidr32ZSzg","map_options":{"id":"3351ba3e-a735-4017-b33f-223d46b16e45","type":"GMapOptions"},"renderers":[{"id":"4926c67a-42d2-4f2f-afe9-dfe9d4a69482","type":"GlyphRenderer"},{"id":"f04fed8b-c038-4db7-906a-9ec14451d296","type":"BoxAnnotation"}],"title":{"id":"31b4d95b-e1b3-43de-a73b-32bf45fb6558","type":"Title"},"tool_events":{"id":"3325db91-20d8-486c-ad59-d36992e22941","type":"ToolEvents"},"toolbar":{"id":"78722629-9911-418c-aa65-6fe62042076f","type":"Toolbar"},"x_range":{"id":"d17971d7-aaac-40e1-a26a-2a86825526ef","type":"DataRange1d"},"x_scale":{"id":"cd17af12-7740-48d3-b6c2-2adce8b3e9f4","type":"LinearScale"},"y_range":{"id":"3a98870f-a53a-41a4-95a1-668e2e049733","type":"DataRange1d"},"y_scale":{"id":"db3ec223-58b3-4d44-891f-179aa73e501a","type":"LinearScale"}},"id":"c0ca1514-70ce-4fac-91df-7c1c485d6f3f","type":"GMapPlot"},{"attributes":{},"id":"3325db91-20d8-486c-ad59-d36992e22941","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":[40.75218887499999,40.67975333333333,40.74155469999999],"lon":[-73.97782175,-73.94044283333334,-73.9857844]}},"id":"156fb1d6-5776-4c38-81e2-86d6873d4fc1","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"47ad92ef-f0f6-49ed-b7e5-c2f5ea132091","type":"Circle"},{"attributes":{"callback":null},"id":"d17971d7-aaac-40e1-a26a-2a86825526ef","type":"DataRange1d"},{"attributes":{"plot":{"id":"c0ca1514-70ce-4fac-91df-7c1c485d6f3f","type":"GMapPlot"}},"id":"8353362e-47c6-4243-b679-392bbcc009e1","type":"WheelZoomTool"},{"attributes":{},"id":"cd17af12-7740-48d3-b6c2-2adce8b3e9f4","type":"LinearScale"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f04fed8b-c038-4db7-906a-9ec14451d296","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"3a98870f-a53a-41a4-95a1-668e2e049733","type":"DataRange1d"},{"attributes":{},"id":"db3ec223-58b3-4d44-891f-179aa73e501a","type":"LinearScale"},{"attributes":{"data_source":{"id":"156fb1d6-5776-4c38-81e2-86d6873d4fc1","type":"ColumnDataSource"},"glyph":{"id":"47ad92ef-f0f6-49ed-b7e5-c2f5ea132091","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"4926c67a-42d2-4f2f-afe9-dfe9d4a69482","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"178a3965-455f-4174-a55c-f6b7920010e0","type":"PanTool"},{"id":"8353362e-47c6-4243-b679-392bbcc009e1","type":"WheelZoomTool"},{"id":"d0e34465-021e-4a52-af2c-e6c2f9a262d2","type":"BoxSelectTool"}]},"id":"78722629-9911-418c-aa65-6fe62042076f","type":"Toolbar"}],"root_ids":["c0ca1514-70ce-4fac-91df-7c1c485d6f3f"]},"title":"Bokeh Application","version":"0.12.6"}};
#             var render_items = [{"docid":"d1745fea-f799-49c8-99e9-058d7883f39c","elementid":"f533f134-19fa-4bcb-92e0-5c5eb95d46c4","modelid":"c0ca1514-70ce-4fac-91df-7c1c485d6f3f"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (forc
